# %%
import numpy as np
import pandas as pd
import os
import requests
from time import sleep
from pathlib import Path

import torch
from transformers import GPT2Tokenizer

# %%
local_dir = Path(os.getcwd())
data_dir = local_dir / 'llm-detect-ai-generated-text'
external_data_dir = local_dir / 'external-data'

# %% [markdown]
# ### Load Data

# %%
train_essays = pd.read_csv(data_dir / 'train_essays.csv')
train_prompts = pd.read_csv(data_dir / 'train_prompts.csv')

train_essays = train_essays.merge(train_prompts, on='prompt_id', how='left')

# %%
# Persuade data
persuade_data = pd.read_csv(external_data_dir / 'Persuade' / 'persuade_2.csv')
persuade_data.rename(columns={'prompt_name': 'prompt_id', 'holistic_essay_score': 'score'}, inplace=True)
persuade_data['generated'] = 0
persuade_data['dataset'] = 'persuade'
persuade_data['source'] = persuade_data['prompt_id']

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
def predict_words_gpt2(sentence):
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model = GPT2LMHeadModel.from_pretrained('gpt2')

    tokens = tokenizer.encode(sentence, return_tensors='pt')
    for i in range(tokens.size(1) - 1):
        input_tokens = tokens[:, :i+1]
        target_token = tokens[:, i+1].tolist()  # Convert tensor to list

        with torch.no_grad():
            outputs = model(input_tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, -1])
        top_50 = torch.topk(probabilities, 50, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token[0]].item()  # Access the first element of the list

        print(f'Target word: {tokenizer.decode(target_token)}')  # No need for list brackets here
        print('Probability of actual word:', actual_word_prob)

sentence = persuade_data['text'][0]
predict_words_gpt2(sentence)

# %%
from transformers import BertForMaskedLM, BertTokenizer

def predict_words_bert(sentence):
    tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
    model = BertForMaskedLM.from_pretrained('bert-base-cased')

    tokens = tokenizer.encode(sentence, return_tensors='pt')
    for i in range(tokens.size(1)):
        masked_index = i
        masked_tokens = tokens.clone()
        masked_tokens[0, masked_index] = tokenizer.mask_token_id

        with torch.no_grad():
            outputs = model(masked_tokens, labels=tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=0)
        probabilities = softmax(logits[0, masked_index])
        top_50 = torch.topk(probabilities, 50, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[tokens[0, masked_index]].item()

        print(f'Masked word: {tokenizer.decode([tokens[0, masked_index]])}')
        print('Top 50 predictions:', top_50_words)
        print('Probability of actual word:', actual_word_prob)

sentence = 'Your example sentence here.'
predict_words_bert(sentence)

# %%
from transformers import DebertaV2Tokenizer, DebertaV2ForMaskedLM

def predict_words_deberta(sentence):
    tokenizer = DebertaV2Tokenizer.from_pretrained('microsoft/deberta-v3-base')
    model = DebertaV2ForMaskedLM.from_pretrained('microsoft/deberta-v3-base')

    tokens = tokenizer.encode(sentence, return_tensors='pt')
    for i in range(1, tokens.size(1) - 1):  # Skipping the first and last tokens ([CLS] and [SEP])
        masked_tokens = tokens.clone()
        masked_tokens[0, i] = tokenizer.mask_token_id
        target_token = tokens[0, i]

        with torch.no_grad():
            outputs = model(masked_tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, i])
        top_50 = torch.topk(probabilities, 50, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token].item()

        print(f'Masked word: {tokenizer.decode([target_token])}')
        print('Top 50 predictions:', top_50_words)
        print('Probability of actual word:', actual_word_prob)

sentence = 'Your example sentence here.'
predict_words_deberta(sentence)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

def predict_words_deberta(sentence):
    tokenizer = AutoTokenizer.from_pretrained('roberta-base')
    model = AutoModelForMaskedLM.from_pretrained('roberta-base')

    tokens = tokenizer.encode(sentence, return_tensors='pt')
    for i in range(1, tokens.size(1) - 1):  # Skipping the first and last tokens ([CLS] and [SEP])
        masked_tokens = tokens.clone()
        masked_tokens[0, i] = tokenizer.mask_token_id
        target_token = tokens[0, i]

        with torch.no_grad():
            outputs = model(masked_tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, i])
        top_50 = torch.topk(probabilities, 10, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token].item()
        top_word_prob = probabilities[top_50.indices[0]].item()
        choice_ratio = actual_word_prob / top_word_prob

        print(f'Masked word: {tokenizer.decode([target_token])}')
        print('Probability of actual word:', actual_word_prob)
        print('Choice ratio:', choice_ratio)
        print('Top 10 predictions:', top_50_words, end='\n\n')

sentence = persuade_data['text'][0]
predict_words_deberta(sentence)

# %%
tokenizer = AutoTokenizer.from_pretrained('roberta-base')

# %%
test = '   test '
trimmed_test = test.strip()
print(trimmed_test)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

def predict_words_deberta(sentence):
    tokenizer = AutoTokenizer.from_pretrained('roberta-base')
    model = AutoModelForMaskedLM.from_pretrained('roberta-base')

    tokens = tokenizer.encode(sentence, return_tensors='pt')
    for i in range(1, tokens.size(1) - 1):  # Skipping the first and last tokens ([CLS] and [SEP])
        masked_tokens = tokens.clone()
        masked_tokens[0, i] = tokenizer.mask_token_id
        target_token = tokens[0, i]

        with torch.no_grad():
            outputs = model(masked_tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, i])
        top_50 = torch.topk(probabilities, 10, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token].item()
        top_word_prob = probabilities[top_50.indices[0]].item()
        choice_ratio = actual_word_prob / top_word_prob

        print(f'Masked word: {tokenizer.decode([target_token])}')
        print('Probability of actual word:', actual_word_prob)
        print('Choice ratio:', choice_ratio)
        print('Top 10 predictions:', top_50_words, end='\n\n')

# %%
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained('roberta-base')
model = AutoModelForMaskedLM.from_pretrained('roberta-base')

text = train_essays['text'][0]
sentence_list = text.split('.')

# %%
def find_sublist(sub, larger):
    """Find the start and end index of a sublist in a larger list."""
    if not isinstance(larger, list):
        larger = larger.tolist()
        
    if not isinstance(sub, list):
        sub = sub.tolist()
        
    for i in range(len(larger)-len(sub)+1):
        if larger[i:i+len(sub)] == sub:
            return i, i+len(sub)
    return -1, -1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
import concurrent.futures

# Initialize tokenizer and model for GPT-2
tokenizer = AutoTokenizer.from_pretrained('distilgpt2')
model = AutoModelForCausalLM.from_pretrained('distilgpt2')
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Downloading (…)lve/main/config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
text = train_essays['text'][0]  # Your text data

# Process text
sentences = [sentence.strip() for sentence in text.split('.') if sentence.strip()]
section = '. '.join(sentences) + '.'

tokens = tokenizer.encode(section, return_tensors='pt')

# Define context window size
context_window_size = 128

def predict_context(i):
    # Define context window
    start_index = max(0, i - context_window_size)
    end_index = i + 1

    # Extract context tokens
    context_tokens = tokens[:, start_index:end_index]

    with torch.no_grad():
        outputs = model(context_tokens)
        logits = outputs.logits

    # Process logits
    softmax = torch.nn.Softmax(dim=-1)
    probabilities = softmax(logits[0, -1])  # Only the last token's probabilities

    # Top 10 predictions
    top_10_indices = torch.topk(probabilities, 5).indices.tolist()
    top_10_words = tokenizer.decode(top_10_indices)

    # Print information
    context_text = tokenizer.decode(context_tokens[0])
    return f'Context: {context_text}\nTop 10 predictions: {top_10_words}\n'

# Create a ThreadPoolExecutor with a specified number of threads (adjust as needed)
num_threads = 5 # You can adjust this based on your available CPU/GPU resources
with concurrent.futures.ThreadPoolExecutor(max_workers=num_threads) as executor:
    results = list(executor.map(predict_context, range(tokens.size(1))))

# Print the results
for result in results:
    print(result)
# Out:
# Context: C
# Top 10 predictions:  The. A
# The
#
# Context: Cars
# Top 10 predictions: ., and are in
#
# Context: Cars.
# Top 10 predictions: com
# orgnet The
#
# Context: Cars. Cars
# Top 10 predictions: . are, and can
#
# Context: Cars. Cars have
# Top 10 predictions:  been a to the become
#
# Context: Cars. Cars have been
# Top 10 predictions:  in banned used built on
#
# Context: Cars. Cars have been around
# Top 10 predictions:  for since in the forever
#
# Context: Cars. Cars have been around since
# Top 10 predictions:  the they 18 2000 9
#
# Context: Cars. Cars have been around since they
# Top 10 predictions:  were first started began came
#
# Context: Cars. Cars have been around since they became
# Top 10 predictions:  popular a the extinct so
#
# Context: Cars. Cars have been around since they became famous
# Top 10 predictions: ., in and for
#
# Context: Cars. Cars have been around since they became famous in
# Top 10 predictions:  the their America a Hollywood
#
# Context: Cars. Cars have been around since they became famous in the
# Top 10 predictions:  early late 1970 1960 1950
#
# Context: Cars. Cars have been around since they became famous in the 1900
# Top 10 predictions: s's�′-
#
# Context: Cars. Cars have been around since they became famous in the 1900s
# Top 10 predictions: ., and when;
#
# Context: Cars. Cars have been around since they became famous in the 1900s,
# Top 10 predictions:  and but when with as
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when
# Top 10 predictions:  the they a it cars
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry
# Top 10 predictions:  Ford VIII James V the
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford
# Top 10 predictions:  was, and introduced began
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created
# Top 10 predictions:  the a Ford his them
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and
# Top 10 predictions:  built sold developed produced created
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built
# Top 10 predictions:  the a cars his an
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the
# Top 10 predictions:  Ford first Model world iconic
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first
# Top 10 predictions:  Ford cars car modern automobile
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first Model
# Top 10 predictions:  X S 3 T A
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT
# Top 10 predictions: ., in and car
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT.
# Top 10 predictions:
#  Cars The Ford In
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars
# Top 10 predictions:  have are were like that
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have
# Top 10 predictions:  been also become always since
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played
# Top 10 predictions:  a an the in with
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a
# Top 10 predictions:  major significant part role huge
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major
# Top 10 predictions:  role part roles factor influence
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role
# Top 10 predictions:  in as throughout, since
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in
# Top 10 predictions:  the many modern this driving
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our
# Top 10 predictions:  lives history culture society understanding
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every
# Top 10 predictions: - dayday move generation
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day
# Top 10 predictions:  life lives of, and
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives
# Top 10 predictions: ., and today in
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since
# Top 10 predictions:  the then., they
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then
# Top 10 predictions: ., and: as
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then.
# Top 10 predictions:
#  Cars We<|endoftext|> The
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But
# Top 10 predictions:  the today we now in
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now
# Top 10 predictions: , we they the that
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now,
# Top 10 predictions:  we the with cars it
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people
# Top 10 predictions:  are have want like who
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are
# Top 10 predictions:  starting turning realizing taking getting
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting
# Top 10 predictions:  to a their out the
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to
# Top 10 predictions:  realize notice see think understand
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question
# Top 10 predictions:  whether the why what how
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if
# Top 10 predictions:  they the we cars there
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting
# Top 10 predictions:  the their cars our car
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car
# Top 10 predictions:  ownership sales production size use
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage
# Top 10 predictions:  is can to and will
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would
# Top 10 predictions:  be help make actually have
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be
# Top 10 predictions:  a the enough beneficial good
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a
# Top 10 predictions:  good great better wise viable
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good
# Top 10 predictions:  idea thing way solution strategy
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing
# Top 10 predictions: . for, or to
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing.
# Top 10 predictions:
# <|endoftext|> The In We
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To
# Top 10 predictions:  answer find be do get
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me
# Top 10 predictions: , it the that this
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me,
# Top 10 predictions:  it limiting the this that
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting
# Top 10 predictions:  car cars the vehicle automobile
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the
# Top 10 predictions:  number use amount car size
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use
# Top 10 predictions:  of and or is for
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of
# Top 10 predictions:  cars a car automobiles the
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars
# Top 10 predictions:  is to for in has
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might
# Top 10 predictions:  be not actually seem help
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be
# Top 10 predictions:  a the an just one
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a
# Top 10 predictions:  good great bad better big
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good
# Top 10 predictions:  idea thing way solution sign
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing
# Top 10 predictions: ., for and because
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to
# Top 10 predictions:  do avoid have be keep
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do
# Top 10 predictions: ., in and if
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do.
# Top 10 predictions:
#  But I<|endoftext|> It
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In
# Top 10 predictions:  fact the my a this
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like
# Top 10 predictions: - a the case many
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter
# Top 10 predictions:  of,- to for
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of
# Top 10 predictions:  cars car the automobiles a
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this
# Top 10 predictions: , article I one we
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this,
# Top 10 predictions:  I it we limiting the
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article
# Top 10 predictions:  is will I has,
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article,
# Top 10 predictions:  I we you the it
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "
# Top 10 predictions: HowTheWhyWhatCar
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In
# Top 10 predictions: vent the acar an
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German
# Top 10 predictions: , Cars car cars"
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Sub
# Top 10 predictions: urbanwaysurb-aru
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb
# Top 10 predictions: iaicineinesism
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb,
# Top 10 predictions:  the a Cars Car BMW
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life
# Top 10 predictions:  in Is is and on
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes
# Top 10 predictions:  On on by By to
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On
# Top 10 predictions: ".","".",
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without
# Top 10 predictions:  Cars Limits a Car the
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars
# Top 10 predictions: ".","",".
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars,"
# Top 10 predictions:  is by will was a
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by
# Top 10 predictions:  the Thomas Mark Wolfgang Max
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth
# Top 10 predictions:  W C M L S
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal
# Top 10 predictions: , and. ( of
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states
# Top 10 predictions:  that:, " the
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states,
# Top 10 predictions:  "
#  "[ the "...
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how
# Top 10 predictions:  to the we you a
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles
# Top 10 predictions:  are can have were work
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are
# Top 10 predictions:  changing becoming used " being
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the
# Top 10 predictions:  " most best only driving
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the l
# Top 10 predictions: inchovableoneladsagg
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linch
# Top 10 predictions: pinpinspwner
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin
# Top 10 predictions:  of in for to behind
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of
# Top 10 predictions:  the our a society driving
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs
# Top 10 predictions: . and, in:
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs,
# Top 10 predictions:  and where " the which
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where
# Top 10 predictions:  cars people the they you
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle
# Top 10 predictions:  class- and classes school
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class
# Top 10 predictions:  families people cars and suburban
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families
# Top 10 predictions:  are live have and can
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from
# Top 10 predictions:  the all low suburban a
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either
# Top 10 predictions:  the side of a major
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai
# Top 10 predictions:  or, to and (
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or
# Top 10 predictions:  Berlin Frankfurt Shanghai New Beijing
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago
# Top 10 predictions:  are live have can get
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend
# Top 10 predictions:  to not toward the more
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to
# Top 10 predictions:  live drive have be spend
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make
# Top 10 predictions:  up the a their more
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their
# Top 10 predictions:  way homes lives living own
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes
# Top 10 predictions: . more and on less
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes.
# Top 10 predictions:
#  " The In It
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts
# Top 10 predictions:  say have agree from believe
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say
# Top 10 predictions:  that the this they limiting
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how
# Top 10 predictions:  cars the many to car
#
# Context: Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how this
# Top 10 predictions:  can affects could works is
#
# Context: ars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how this is
# Top 10 predictions:  done possible changing different happening
#
# Context: . Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how this is a
# Top 10 predictions:  good big bad very great
#
# Context:  Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how this is a huge
# Top 10 predictions:  problem influence advantage boon deal
#
# Context:  have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how this is a huge imped
# Top 10 predictions: imentimentsientiones
#
# Context:  been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do. In like matter of this, article, "In German Suburb, Life Goes On Without Cars," by Elizabeth Rosenthal states, how automobiles are the linchpin of suburbs, where middle class families from either Shanghai or Chicago tend to make their homes. Experts say how this is a huge impediment
# Top 10 predictions:  to for, in of
#
# ...
# Top 10 predictions:  of or to,.
#
# Context:  traffic jams have gone down, and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of
# Top 10 predictions:  cars a your any the
#
# Context:  jams have gone down, and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a
# Top 10 predictions:  car bike bicycle lot vehicle
#
# Context:  have gone down, and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car
# Top 10 predictions: ., to for or
#
# Context:  gone down, and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to
# Top 10 predictions:  drive get do be make
#
# Context:  down, and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get
# Top 10 predictions:  to there around off in
#
# Context: , and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you
# Top 10 predictions:  there to out on back
#
# Context:  and restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there
# Top 10 predictions: ., or and in
#
# Context:  restaurants and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there.
# Top 10 predictions:
# <|endoftext|> We The But
#
# Context:  and shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To
# Top 10 predictions:  do that be me make
#
# Context:  shopping districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me
# Top 10 predictions: , it the that this
#
# Context:  districts have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me,
# Top 10 predictions:  the it that this we
#
# Context:  have popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting
# Top 10 predictions:  the cars use our it
#
# Context:  popped up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the
# Top 10 predictions:  use usage number amount uses
#
# Context:  up, all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use
# Top 10 predictions:  of and or by is
#
# Context: , all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of
# Top 10 predictions:  cars vehicles automobiles car a
#
# Context:  all due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars
# Top 10 predictions:  is by would in and
#
# Context:  due to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might
# Top 10 predictions:  be not actually have help
#
# Context:  to the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be
# Top 10 predictions:  a the an good one
#
# Context:  the fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be a
# Top 10 predictions:  good better great bad big
#
# Context:  fact of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be a good
# Top 10 predictions:  thing idea way solution sign
#
# Context:  of having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be a good thing
# Top 10 predictions:  for., and because
#
# Context:  having less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be a good thing to
# Top 10 predictions:  do reduce have be the
#
# Context:  less cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be a good thing to do
# Top 10 predictions: ., in and for
#
# Context:  cars around. In conclusion, the use of less cars and having carfree days, have had a big impact on the environment of cities because, it is cutting down the air pollution that the cars have majorly polluted, it has aloud countries like Columbia to repair sidewalks, and cut down traffic jams. Limiting the use of cars would be a good thing for America. So we should limit the use of cars by maybe riding a bike, or maybe walking somewhere that isn't that far from you and doesn't need the use of a car to get you there. To me, limiting the use of cars might be a good thing to do.
# Top 10 predictions:
# <|endoftext|> But I It

# %%
sentence_list = text.split('.')
sentence_list = [sentence.strip() for sentence in sentence_list]
sentence_list = [sentence for sentence in sentence_list if sentence]

for i, sentence in enumerate(sentence_list):
    print('New Sentence!', end='\n\n')
    section_start = max(i - 2, 0)
    section_end = min(i + 1, len(sentence_list))
    section = '. '.join(sentence_list[section_start:section_end]).strip()
    if not section.endswith('. '):
        section += '.'

    # Tokenize the section
    tokens = tokenizer(section, return_tensors='pt', add_special_tokens=False)
    if i == 0:
        sentence_tokens = tokenizer.encode(sentence_list[i] + '.', add_special_tokens=False)
    else:
        sentence_tokens = tokenizer.encode(' ' + sentence_list[i] + '.', add_special_tokens=False)
    
    # Find the index of the target sentence
    sentence_start, sentence_end = find_sublist(sentence_tokens, tokens['input_ids'][0])
    
    # Mask each token from sentence_start to sentence_end
    for i in range(sentence_start, sentence_end):
        masked_tokens = tokens['input_ids'].clone()
        masked_tokens[0, i] = tokenizer.mask_token_id
        masked_tokens = masked_tokens[0, 0:i+2].unsqueeze(0)
        target_token = tokens['input_ids'][0, i]

        with torch.no_grad():
            outputs = model(masked_tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, i])
        top_50 = torch.topk(probabilities, 10, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token].item()
        top_word_prob = probabilities[top_50.indices[0]].item()
        choice_ratio = actual_word_prob / top_word_prob

        print(f'Masked word: {tokenizer.decode([target_token])}')
        print('Probability of actual word:', actual_word_prob)
        print('Choice ratio:', choice_ratio)
        print('Top 10 predictions:', top_50_words, end='\n\n')
# Out:
# New Sentence!
#
# Masked word: C
# Probability of actual word: 1.5746464462201848e-14
# Choice ratio: 1.5746475724958953e-14
# Top 10 predictions: ['<s>', '</s>', '.', '<mask>', '?', ',', '!', '...', ']', ' (']
#
# Masked word: ars
# Probability of actual word: 7.012762637259584e-08
# Choice ratio: 6.509847680793971e-07
# Top 10 predictions: ['6', '4', '3', '5', '2', '7', '10', '8', '9', 'III']
#
# Masked word: .
# Probability of actual word: 0.007346807979047298
# Choice ratio: 0.007405862983616421
# Top 10 predictions: ['</s>', '.', '<s>', ']', ').', ' (', ' "', ')', ':', '."']
#
# New Sentence!
#
# Masked word:  Cars
# Probability of actual word: 7.274016297742492e-06
# Choice ratio: 4.090514278049207e-05
# Top 10 predictions: ['com', '</s>', 'net', 'js', 'txt', 'org', 'xx', 'xxx', 'gov', 'jpg']
#
# Masked word:  have
# Probability of actual word: 0.03110678307712078
# Choice ratio: 0.05142232917036161
# Top 10 predictions: ['.', ' have', '?', '...', ':', ' Edit', ',', '!', ' and', ' […]']
#
# Masked word:  been
# Probability of actual word: 0.3545325696468353
# Choice ratio: 1.0
# Top 10 predictions: [' been', ' gone', ' turned', ' moved', ' gotten', ' come', ' flown', ' Posted', ' rolled', ' stuck']
#
# Masked word:  around
# Probability of actual word: 0.8579930067062378
# Choice ratio: 1.0
# Top 10 predictions: [' around', ' made', ' used', ' built', ' here', ' making', ' cool', ' manufactured', ' obsolete', ' driving']
#
# Masked word:  since
# Probability of actual word: 0.8982552289962769
# Choice ratio: 1.0
# Top 10 predictions: [' since', ',', ' and', ' because', ' before', ' for', ' …', ' as', ' but', ' like']
#
# Masked word:  they
# Probability of actual word: 0.08079981803894043
# Choice ratio: 0.45112192199937184
# Top 10 predictions: ['.', ' dinosaurs', ' they', ' cars', '...', ' the', ' we', ' antiquity', ' automobiles', ' Columbus']
#
# Masked word:  became
# Probability of actual word: 0.004044344183057547
# Choice ratio: 0.012110967872649704
# Top 10 predictions: [' were', ' started', ' began', ' came', '.', ' first', ' appeared', '...', ' arrived', "'re"]
#
# Masked word:  famous
# Probability of actual word: 0.013461733236908913
# Choice ratio: 0.07204382025186902
# Top 10 predictions: [' popular', ' available', ' commonplace', ' fashionable', ' ubiquitous', ' common', ' cars', '...', ' extinct', ' a']
#
# Masked word:  in
# Probability of actual word: 0.36043140292167664
# Choice ratio: 1.0
# Top 10 predictions: [' in', '.', ',', ' as', ' on', ' and', ' for', ';', ' with', ':']
#
# Masked word:  the
# Probability of actual word: 0.32880428433418274
# Choice ratio: 1.0
# Top 10 predictions: [' the', ' America', ' cars', ' a', ' 1900', '</s>', ' The', ' 1910', ' Europe', ' 1930']
#
# Masked word:  1900
# Probability of actual word: 0.007377327419817448
# Choice ratio: 0.029157481410991906
# Top 10 predictions: [' 1950', ' 1960', ' 1930', ' 1920', ' 1970', ' 1800', ' 1940', ' 1980', ' 70', ' 1880']
#
# Masked word: s
# Probability of actual word: 0.7056363224983215
# Choice ratio: 1.0
# Top 10 predictions: ['s', "'s", ' years', ' era', ' century', ',', ' period', ' s', '.', ' year']
#
# Masked word: ,
# Probability of actual word: 0.9930927753448486
# Choice ratio: 1.0
# Top 10 predictions: [',', ' —', ' -', ' –', ' --', ',', ';', ' ―', '.,', ' �']
#
# Masked word:  when
# Probability of actual word: 0.015448296442627907
# Choice ratio: 0.06099847426975471
# Top 10 predictions: [' but', '</s>', ' and', ' by', ' when', ' says', ' as', ' a', ' the', ' say']
#
# Masked word:  Henry
# Probability of actual word: 0.8723585605621338
# Choice ratio: 1.0
# Top 10 predictions: [' Henry', ' George', ' the', ' John', ' a', ' Harrison', ' Charles', ' President', ' Robert', ' Benjamin']
#
# Masked word:  Ford
# Probability of actual word: 0.9658994674682617
# Choice ratio: 1.0
# Top 10 predictions: [' Ford', ' Miller', ' Moore', ' Hudson', ' Clay', ' Cooper', ' Wallace', ' Jackson', ' Burr', ' Harrison']
#
# Masked word:  created
# Probability of actual word: 0.05322656035423279
# Choice ratio: 0.17613315289908799
# Top 10 predictions: [' invented', ' built', ' designed', ' started', ' created', ' developed', ' made', ' introduced', ' founded', ' began']
#
# Masked word:  and
# Probability of actual word: 0.059676289558410645
# Choice ratio: 0.1846731207444754
# Top 10 predictions: [' them', '.', '...', ' and', ' the', ' one', ' a', '.', '...', ' it']
#
# Masked word:  built
# Probability of actual word: 0.06802114099264145
# Choice ratio: 0.44394880919326046
# Top 10 predictions: [' drove', ' patented', ' marketed', ' sold', ' built', ' raced', ' financed', ' maintained', ' ran', ' used']
#
# Masked word:  the
# Probability of actual word: 0.928082287311554
# Choice ratio: 1.0
# Top 10 predictions: [' the', ' his', ' our', ' their', ' America', ' its', ' those', ' that', ' these', ' he']
#
# Masked word:  first
# Probability of actual word: 0.3069469928741455
# Choice ratio: 1.0
# Top 10 predictions: [' first', ' Ford', ' Late', ' First', ' original', ' famous', ' Lincoln', ' late', ' early', ' Standard']
#
# Masked word:  Model
# Probability of actual word: 0.17450100183486938
# Choice ratio: 0.6423853411104843
# Top 10 predictions: ['.', ' Model', ' automobile', ' Ford', ' car', ' model', ' sedan', ' prototype', ' convertible', ' GT']
#
# Masked word: T
# Probability of actual word: 0.00016094540478661656
# Choice ratio: 0.00017170330693929233
# Top 10 predictions: [' T', ' S', ' A', ' N', ' E', ' B', ' 3', ' I', ' R', ' City']
#
# Masked word: .
# Probability of actual word: 1.981209970836062e-05
# Choice ratio: 1.9813587745503333e-05
# Top 10 predictions: ['</s>', '.', ' (', ' "', '<s>', '...', '.', ',', ',', '—']
#
# New Sentence!
#
# Masked word:  Cars
# Probability of actual word: 0.7520034909248352
# Choice ratio: 1.0
# Top 10 predictions: [' Cars', ' Others', ' They', ' Many', ' Some', ' We', ' More', ' People', ' But', ' And']
#
# Masked word:  have
# Probability of actual word: 0.24133740365505219
# Choice ratio: 1.0
# Top 10 predictions: [' have', '.', '</s>', '?', ' are', ':', ' also', ' still', '!', '...']
#
# Masked word:  played
# Probability of actual word: 0.015169956721365452
# Choice ratio: 0.020609978870510668
# Top 10 predictions: [' been', ' become', ' had', ' played', ' enjoyed', ' remained', ' always', ' provided', ' made', ' served']
#
# Masked word:  a
# Probability of actual word: 0.678306519985199
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' the', ' every', ' many', ' important', ' roles', ' major', ' no', '</s>', '.']
#
# Masked word:  major
# Probability of actual word: 0.2776387929916382
# Choice ratio: 1.0
# Top 10 predictions: [' major', ' significant', ' central', ' key', ' prominent', ' huge', ' big', ' pivotal', ' leading', ' crucial']
#
# Masked word:  role
# Probability of actual word: 0.6853765249252319
# Choice ratio: 1.0
# Top 10 predictions: [' role', ' part', ' factor', ' hand', ' roll', ' place', ' influence', ' roles', ' component', ' share']
#
# Masked word:  in
# Probability of actual word: 0.6311079263687134
# Choice ratio: 1.0
# Top 10 predictions: [' in', '.', '</s>', ' since', ' as', ',', ' of', ' on', ' to', ' that']
#
# Masked word:  our
# Probability of actual word: 0.14274773001670837
# Choice ratio: 0.4253344640494437
# Top 10 predictions: [' almost', ' nearly', ' our', ' virtually', ' the', ' most', ' American', ' practically', ' America', ' making']
#
# Masked word:  every
# Probability of actual word: 0.15629373490810394
# Choice ratio: 0.21970898197441607
# Top 10 predictions: [' modern', ' every', ' present', ' current', ' automotive', ' working', ' day', ' everyday', ' daily', ' each']
#
# Masked word:  day
# Probability of actual word: 0.976891815662384
# Choice ratio: 1.0
# Top 10 predictions: [' day', 'day', ' waking', ' minute', ' Day', ' daily', ' year', ' morning', ' night', ' days']
#
# Masked word:  lives
# Probability of actual word: 0.9328095316886902
# Choice ratio: 1.0
# Top 10 predictions: [' lives', ' life', ' existence', ' activities', ' lifestyle', ' routines', ' living', ' experience', ' interactions', ' routine']
#
# Masked word:  since
# Probability of actual word: 0.9973145127296448
# Choice ratio: 1.0
# Top 10 predictions: [' since', ' from', ' and', ',', ' ever', ' back', ' until', ' even', ' Since', ' more']
#
# Masked word:  then
# Probability of actual word: 0.9734198451042175
# Choice ratio: 1.0
# Top 10 predictions: [' then', '.', ' inception', ' 1901', ' Then', ' 1950', ' 1886', ' birth', ' that', ' childhood']
#
# Masked word: .
# Probability of actual word: 0.0005635505076497793
# Choice ratio: 0.0005639209488944868
# Top 10 predictions: ['</s>', '.', ',', '—', ' (', '.', ' and', ';', ' "', '…']
#
# New Sentence!
#
# Masked word:  But
# Probability of actual word: 0.13535967469215393
# Choice ratio: 0.245390284657932
# Top 10 predictions: [' And', ' Even', ' But', ' Until', ' Especially', ' Except', ' Right', ' For', ' and', ' More']
#
# Masked word:  now
# Probability of actual word: 0.3213479220867157
# Choice ratio: 1.0
# Top 10 predictions: [' now', ' today', ' mostly', ' first', ' recently', ' lately', ' still', ' mainly', ' then', ' wait']
#
# Masked word: ,
# Probability of actual word: 0.25700804591178894
# Choice ratio: 1.0
# Top 10 predictions: [',', ' more', '.', ' most', ' many', '...', ' we', ' the', 'adays', '…']
#
# Masked word:  people
# Probability of actual word: 0.00674266554415226
# Choice ratio: 0.014538594831064558
# Top 10 predictions: [' they', ' cars', ' we', ' more', ' there', ' EVs', ' fewer', ' things', ' people', ' automobiles']
#
# Masked word:  are
# Probability of actual word: 0.9633079767227173
# Choice ratio: 1.0
# Top 10 predictions: [' are', ' just', ' have', ' really', ' see', ' realize', ' finally', "'re", ' can', ' understand']
#
# Masked word:  starting
# Probability of actual word: 0.7072692513465881
# Choice ratio: 1.0
# Top 10 predictions: [' starting', ' beginning', ' turning', ' learning', ' changing', ' looking', ' coming', ' able', ' afraid', ' trying']
#
# Masked word:  to
# Probability of actual word: 0.999922513961792
# Choice ratio: 1.0
# Top 10 predictions: [' to', ' the', ' some', ' too', ' a', ' their', ' into', ' asking', ' seriously', ' ta']
#
# Masked word:  question
# Probability of actual word: 0.593574047088623
# Choice ratio: 1.0
# Top 10 predictions: [' question', ' wonder', ' ask', ' rethink', ' reconsider', ' think', ' stop', ' worry', ' doubt', ' understand']
#
# Masked word:  if
# Probability of actual word: 5.6906224926933646e-05
# Choice ratio: 7.048933737713457e-05
# Top 10 predictions: ['.', '...', ' why', ' that', ':', '…', ' them', ' it', ' this', '.']
#
# Masked word:  limiting
# Probability of actual word: 6.008472155372147e-07
# Choice ratio: 1.596184109286861e-06
# Top 10 predictions: [' their', ' a', ' they', ' your', ' the', ' that', ' you', ' every', ' any', ' this']
#
# Masked word:  car
# Probability of actual word: 0.019950512796640396
# Choice ratio: 0.06786355123133109
# Top 10 predictions: ['.', ' their', ' are', ' is', ' have', "'s", ' car', ' cars', ' should', ' the']
#
# Masked word:  usage
# Probability of actual word: 0.011727821081876755
# Choice ratio: 0.015004262934587316
# Top 10 predictions: [' ownership', ' use', ' purchases', ' sales', ' usage', ' production', ' owners', ' purchase', ' driving', ' prices']
#
# Masked word:  would
# Probability of actual word: 0.06118248030543327
# Choice ratio: 0.1447285098847787
# Top 10 predictions: [' should', ' might', ' could', ' can', ' will', ' would', ' may', ' is', ' to', ' needs']
#
# Masked word:  be
# Probability of actual word: 0.8893007040023804
# Choice ratio: 1.0
# Top 10 predictions: [' be', ' make', ' benefit', ' help', ' work', ' have', ' require', ' constitute', ' pose', ' serve']
#
# Masked word:  a
# Probability of actual word: 0.9186493754386902
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' any', ' so', '.', ' as', ' for', ' too', ' the', ' that', ' very']
#
# Masked word:  good
# Probability of actual word: 0.7554213404655457
# Choice ratio: 1.0
# Top 10 predictions: [' good', ' bad', ' positive', ' wise', ' great', ' smart', ' terrible', ' better', ' right', ' healthy']
#
# Masked word:  thing
# Probability of actual word: 0.16629593074321747
# Choice ratio: 0.2076614872048472
# Top 10 predictions: [' idea', ' thing', ' move', ' solution', ' strategy', ' policy', ' option', ' start', ' choice', ' decision']
#
# Masked word: .
# Probability of actual word: 8.891397010302171e-05
# Choice ratio: 8.892384981465292e-05
# Top 10 predictions: ['</s>', '.', '—', ' (', '.', ' —', '."', '…', ' and', ' "']
#
# New Sentence!
#
# Masked word:  To
# Probability of actual word: 0.006460762582719326
# Choice ratio: 0.012680872113469143
# Top 10 predictions: ['</s>', ' Like', ' Just', ' Ask', ' For', ' Trust', ' Take', ' Try', ' Call', ' Tell']
#
# Masked word:  me
# Probability of actual word: 0.1650048792362213
# Choice ratio: 0.7781340843176463
# Top 10 predictions: [' start', ' me', ' them', ' clarify', ' begin', ' some', ' many', ' date', ' answer', ' recap']
#
# Masked word: ,
# Probability of actual word: 0.7078067064285278
# Choice ratio: 1.0
# Top 10 predictions: [',', '.', '?', ':', '...', '…', '...', ' …', '!', '?']
#
# Masked word:  limiting
# Probability of actual word: 0.004764334298670292
# Choice ratio: 0.02964487357661678
# Top 10 predictions: [' that', ' it', ' all', ' what', ' none', ' not', ' quite', ' maybe', ' this', ' why']
#
# Masked word:  the
# Probability of actual word: 0.0006716428324580193
# Choice ratio: 0.0006812968020221672
# Top 10 predictions: [' car', ' vehicle', ' auto', ' cars', ' the', ' automobile', ' my', ' your', ' their', ' its']
#
# Masked word:  use
# Probability of actual word: 0.5223857760429382
# Choice ratio: 1.0
# Top 10 predictions: [' use', ' usage', ' number', ' amount', ' consumption', ' impact', ' cost', ' availability', ' uses', ' size']
#
# Masked word:  of
# Probability of actual word: 0.9959992170333862
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' in', ' your', ' is', ' means', ' by', ' electric', ' for', ' the', ' our']
#
# Masked word:  cars
# Probability of actual word: 0.8308375477790833
# Choice ratio: 1.0
# Top 10 predictions: [' cars', ' car', ' vehicles', ' a', ' automobiles', ' the', ' what', ' gas', ' them', ' which']
#
# Masked word:  might
# Probability of actual word: 0.031187817454338074
# Choice ratio: 0.036996667049423095
# Top 10 predictions: [' would', ' should', ' might', ' may', ' could', ' seems', ' is', ' will', ' can', ' must']
#
# Masked word:  be
# Probability of actual word: 0.9007763862609863
# Choice ratio: 1.0
# Top 10 predictions: [' be', ' seem', ' sound', ' make', ' like', ' signal', ' look', ' prove', ' mean', ' have']
#
# Masked word:  a
# Probability of actual word: 0.9928516745567322
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' very', ' quite', ' pretty', ' actually', ' really', ' the', ' even', ' considered', ' equally']
#
# Masked word:  good
# Probability of actual word: 0.76421719789505
# Choice ratio: 1.0
# Top 10 predictions: [' good', ' bad', ' positive', ' great', ' terrible', ' better', ' smart', ' wise', ' healthy', ' nice']
#
# Masked word:  thing
# Probability of actual word: 0.16366709768772125
# Choice ratio: 0.4359071409946696
# Top 10 predictions: [' way', ' idea', ' thing', ' place', ' start', ' move', ' approach', ' solution', ' option', ' time']
#
# Masked word:  to
# Probability of actual word: 0.0034715894144028425
# Choice ratio: 0.0036754100421301874
# Top 10 predictions: ['.', ':', '!', '...', ' to', '</s>', '…', '?', ',', '."']
#
# Masked word:  do
# Probability of actual word: 0.7113368511199951
# Choice ratio: 1.0
# Top 10 predictions: [' do', ' try', ' consider', ' have', ' happen', ' start', ' avoid', ' see', ' say', ' society']
#
# Masked word: .
# Probability of actual word: 4.9090158427134156e-05
# Choice ratio: 4.909408543520594e-05
# Top 10 predictions: ['</s>', '.', ' and', ' more', ' (', '—', ' that', ' "', ' some', ' because']
#
# New Sentence!
#
# Masked word:  In
# Probability of actual word: 5.323220102582127e-05
# Choice ratio: 9.504103279141436e-05
# Top 10 predictions: ['</s>', ' I', ' More', ' […]', ' [...]', '...', ' Share', '...', ' *', ' "']
#
# Masked word:  like
# Probability of actual word: 2.492329804226756e-05
# Choice ratio: 5.5367412063237536e-05
# Top 10 predictions: [' fact', ' this', ' that', ' a', ' the', ' my', ' general', ' another', ' no', ' some']
#
# Masked word:  matter
# Probability of actual word: 0.0001225673477165401
# Choice ratio: 0.0006389110434826782
# Top 10 predictions: [',', ':', ' case', '.', ' words', '</s>', ' form', ' way', ' the', '...']
#
# Masked word:  of
# Probability of actual word: 0.22216317057609558
# Choice ratio: 0.7600927011081594
# Top 10 predictions: [',', ' of', '...', ':', '.', '…', ' …', ',...', ' -', ' like']
#
# Masked word:  this
# Probability of actual word: 3.9551276131533086e-05
# Choice ratio: 8.755582037057025e-05
# Top 10 predictions: [' fact', ' minutes', ' time', ' hours', ' weeks', ' days', ' seconds', ' months', ' words', ' moments']
#
# Masked word: ,
# Probability of actual word: 0.15125919878482819
# Choice ratio: 0.3250747322308557
# Top 10 predictions: [':', ',', '.', '...', '…', ' case', ' …', ' article', ' week', ' moment']
#
# Masked word:  article
# Probability of actual word: 8.82410768099362e-06
# Choice ratio: 1.9861508532886904e-05
# Top 10 predictions: [' however', ' though', ' well', ' too', ' apparently', ' then', ' say', ' perhaps', ' yes', ' anyway']
#
# Masked word: ,
# Probability of actual word: 0.0335531085729599
# Choice ratio: 0.23673225089774252
# Top 10 predictions: [' titled', ':', ',', ' says', ' entitled', ' reads', ' said', ' :', ' "', ' headlined']
#
# Masked word:  "
# Probability of actual word: 0.06700009107589722
# Choice ratio: 0.38462321501312813
# Top 10 predictions: ['</s>', ' the', ' "', ' I', ' i', ' The', ' a', ' an', ' e', ' #']
#
# Masked word: In
# Probability of actual word: 0.004100245423614979
# Choice ratio: 0.02118639785717437
# Top 10 predictions: ['The', 'A', '"', ' "', '..."', '</s>', ' The', '">', '".', 'a']
#
# Masked word:  German
# Probability of actual word: 0.00029588889447040856
# Choice ratio: 0.003132556405152648
# Top 10 predictions: [' the', ' The', ' a', 'flation', 'visible', ' Cars', 'efficiency', 'formed', 'jury', ' my']
#
# Masked word:  Sub
# Probability of actual word: 0.0009133441490121186
# Choice ratio: 0.0022714063990073976
# Top 10 predictions: ['."', '"', '..."', ' news', ' News', ' language', '.', '",', '".', ',"']
#
# Masked word: urb
# Probability of actual word: 0.014937158674001694
# Choice ratio: 0.03640610260417942
# Top 10 predictions: ['scription', 'reddit', 'marine', 'lime', 'text', 'culture', 'space', '"', 'urb', 's']
#
# Masked word: ,
# Probability of actual word: 0.00044244033051654696
# Choice ratio: 0.0006562104112033423
# Top 10 predictions: ['ia', '"', 'ines', '."', 'ans', 'icon', 'ic', 'ation', 'an', 'es']
#
# Masked word:  Life
# Probability of actual word: 0.015213308855891228
# Choice ratio: 0.3427388650551243
# Top 10 predictions: [' Everything', ' Man', ' Death', ' It', ' Life', ' Everyone', ' Traffic', ' Something', ' Car', ' Fiat']
#
# Masked word:  Goes
# Probability of actual word: 0.17600470781326294
# Choice ratio: 0.7537828661867565
# Top 10 predictions: ['."', ' Goes', '"', ' Is', ' Posted', ' Begins', ' Changes', '.', '?"', '":']
#
# Masked word:  On
# Probability of actual word: 0.6601689457893372
# Choice ratio: 1.0
# Top 10 predictions: [' On', ' on', ' By', ' by', '"', 'On', '.', '."', "'", '".']
#
# Masked word:  Without
# Probability of actual word: 4.981603706255555e-05
# Choice ratio: 0.00012482201923980196
# Top 10 predictions: ['."', '"', '".', '":', '!"', ',"', '..."', ' "', '.', '",']
#
# Masked word:  Cars
# Probability of actual word: 0.8170419931411743
# Choice ratio: 1.0
# Top 10 predictions: [' Cars', ' Car', ' Drivers', ' Us', ' You', ' Them', ' It', ' Vehicles', ' One', ' cars']
#
# Masked word: ,"
# Probability of actual word: 0.1523585319519043
# Choice ratio: 0.615987553260868
# Top 10 predictions: ['."', '"', ',"', '",', '".', '":', '..."', '"...', '?"', '</s>']
#
# Masked word:  by
# Probability of actual word: 0.2622113525867462
# Choice ratio: 1.0
# Top 10 predictions: [' by', ' I', '</s>', ' the', ' see', ' in', ' is', ' a', ' we', ' published']
#
# Masked word:  Elizabeth
# Probability of actual word: 0.0027395158540457487
# Choice ratio: 0.021420513325180496
# Top 10 predictions: [':', ' John', ' the', ' David', ' Daniel', ' a', ',', ' Paul', ' Michael', ' Robert']
#
# Masked word:  Rosenthal
# Probability of actual word: 0.0012521921889856458
# Choice ratio: 0.07574705458101046
# Top 10 predictions: [',', ' Smith', ' Miller', ' Jones', ' Brown', ' Johnson', ' Williams', ' Taylor', ' Cohen', ' Lee']
#
# Masked word:  states
# Probability of actual word: 0.001623088726773858
# Choice ratio: 0.03258272203510169
# Top 10 predictions: [',', ' writes', ' wrote', ' says', ' said', ' reports', ' published', '.', ' reported', ' explains']
#
# Masked word: ,
# Probability of actual word: 0.06824352592229843
# Choice ratio: 0.3105552052385573
# Top 10 predictions: [' about', ' exactly', ' of', ' clearly', ',', ' just', ' on', ' that', ' precisely', ' plainly']
#
# Masked word:  how
# Probability of actual word: 4.825002179131843e-05
# Choice ratio: 8.163457703436799e-05
# Top 10 predictions: [' "', ' "...', '</s>', ' "[', ' "…', ':', " '", ' :', ' that', ' by']
#
# Masked word:  automobiles
# Probability of actual word: 0.003144520800560713
# Choice ratio: 0.01334970060389738
# Top 10 predictions: [' we', ' many', ' cars', ' they', ' things', ' few', ' people', ' you', ' important', ' there']
#
# Masked word:  are
# Probability of actual word: 0.1461222916841507
# Choice ratio: 0.9156915949603304
# Top 10 predictions: [' affect', ' are', ' dominate', ' changed', ' affected', ' impact', ' change', ' influence', ' influenced', ' help']
#
# Masked word:  the
# Probability of actual word: 0.033095940947532654
# Choice ratio: 0.4388352514736884
# Top 10 predictions: [' used', '.', ' a', ' the', ':', '...', ' becoming', ' disappearing', ' not', ' being']
#
# Masked word:  l
# Probability of actual word: 0.0007320582517422736
# Choice ratio: 0.0033806740990713255
# Top 10 predictions: [' problem', ' future', ' norm', ' only', '...', ' solution', ' […]', ' enemy', ' key', '…']
#
# Masked word: inch
# Probability of actual word: 0.9998289346694946
# Choice ratio: 1.0
# Top 10 predictions: ['inch', 'ch', 'igh', 'ining', 'anch', 'ones', 'icks', 'ang', 'arks', 'ing']
#
# Masked word: pin
# Probability of actual word: 0.8625599145889282
# Choice ratio: 1.0
# Top 10 predictions: ['pin', 'pins', 'men', 'p', 'pe', ' belt', ' support', 'olds', 'l', 'line']
#
# Masked word:  of
# Probability of actual word: 0.22055555880069733
# Choice ratio: 0.49444847430922784
# Top 10 predictions: ['.', ' of', '...', ':', '</s>', ' to', '."', ' […]', '…', ',']
#
# Masked word:  suburbs
# Probability of actual word: 0.00010306909825885668
# Choice ratio: 0.0003394208324433996
# Top 10 predictions: [' life', ' society', ' civilization', ' the', ' existence', ' culture', ' living', ' survival', ' everything', ' communities']
#
# Masked word: ,
# Probability of actual word: 0.8966404795646667
# Choice ratio: 1.0
# Top 10 predictions: [',', ' and', ' —', ' -', ' --', ' –', ' in', ';', ' here', ' like']
#
# Masked word:  where
# Probability of actual word: 0.00837888102978468
# Choice ratio: 0.061647856375015554
# Top 10 predictions: [' the', ' a', ' and', '</s>', ' "', ' […]', '.', ' in', ' but', ' as']
#
# Masked word:  middle
# Probability of actual word: 0.00011560547864064574
# Choice ratio: 0.0008433718496472975
# Top 10 predictions: ['.', '...', ' the', '…', ' […]', ' people', ':', ' a', ' they', ' by']
#
# Masked word:  class
# Probability of actual word: 0.9570931196212769
# Choice ratio: 1.0
# Top 10 predictions: [' class', ' income', 'class', ' aged', ' classes', ' American', ' age', ' Class', ' suburban', 'income']
#
# Masked word:  families
# Probability of actual word: 0.012224216014146805
# Choice ratio: 0.02934029955992765
# Top 10 predictions: [' comes', ' come', ' came', ' is', ' people', ' families', ' suffers', ' emerges', ' benefits', ' and']
#
# Masked word:  from
# Probability of actual word: 9.55108625930734e-05
# Choice ratio: 0.00014739066235212013
# Top 10 predictions: [' live', '.', ' reside', ' thrive', ' are', '...', ' dwell', '…', ' stay', ' go']
#
# Masked word:  either
# Probability of actual word: 3.166565511492081e-05
# Choice ratio: 0.00019617587598502384
# Top 10 predictions: [' Germany', ' the', '...', ' a', '…', '.', '</s>', ' […]', ' Europe', '.']
#
# Masked word:  Shanghai
# Probability of actual word: 0.0002003954432439059
# Choice ratio: 0.000654040266068554
# Top 10 predictions: [' Germany', ' rural', ' Detroit', ' Berlin', ' suburb', ' German', ' Chicago', ' Europe', ' Munich', ' Milwaukee']
#
# Masked word:  or
# Probability of actual word: 0.983883798122406
# Choice ratio: 1.0
# Top 10 predictions: [' or', ' to', ',', ' and', ' of', ' nor', ' in', ' the', ' Or', ' OR']
#
# Masked word:  Chicago
# Probability of actual word: 0.01660633459687233
# Choice ratio: 0.07688276256110982
# Top 10 predictions: [' Beijing', ' Berlin', ' Tokyo', ' Frankfurt', ' Shanghai', ' Munich', ' Seoul', ' Paris', ' London', ' Chicago']
#
# Masked word:  tend
# Probability of actual word: 0.009739045985043049
# Choice ratio: 0.0265068774172281
# Top 10 predictions: [' commute', ' come', ' flock', ' travel', ' move', ' go', ' migrate', ' live', ' choose', ' drive']
#
# Masked word:  to
# Probability of actual word: 0.864142656326294
# Choice ratio: 1.0
# Top 10 predictions: [' to', '.', ',', ' not', ':', '.', ' the', '...', ' together', ' and']
#
# Masked word:  make
# Probability of actual word: 0.019297510385513306
# Choice ratio: 0.14112101850304062
# Top 10 predictions: [' get', ' drive', ' bring', ' take', ' have', ' buy', ' send', ' find', ' raise', ' spend']
#
# Masked word:  their
# Probability of actual word: 0.9765468835830688
# Choice ratio: 1.0
# Top 10 predictions: [' their', ' up', ' new', ' themselves', ' them', ' the', ' good', ' permanent', ' it', ' theirs']
#
# Masked word:  homes
# Probability of actual word: 0.14963585138320923
# Choice ratio: 0.4477671065194201
# Top 10 predictions: [' living', ' money', ' homes', ' home', ' fortunes', ' way', ' cars', ' fortune', ' income', ' purchases']
#
# Masked word: .
# Probability of actual word: 0.000162554468261078
# Choice ratio: 0.00016264310310321585
# Top 10 predictions: ['</s>', '.', ',', ' and', '...', '—', '…', ' …', ' (', '...']
#
# New Sentence!
#
# Masked word:  Experts
# Probability of actual word: 0.00020063738338649273
# Choice ratio: 0.0003363214421738951
# Top 10 predictions: ['</s>', ' More', ' […]', '.', ' The', '.', ' We', '...', ' "', '...']
#
# Masked word:  say
# Probability of actual word: 0.007966306060552597
# Choice ratio: 0.048425348876264346
# Top 10 predictions: [' explain', ' show', ' describe', ' discuss', ' explained', ' mention', ' on', ' described', ' detail', ' discussed']
#
# Masked word:  how
# Probability of actual word: 0.0005319972988218069
# Choice ratio: 0.0009242645819601638
# Top 10 predictions: [',', ':', ' that', '.', '...', '…', '...', ',...', ' …', ' this']
#
# Masked word:  this
# Probability of actual word: 0.21068313717842102
# Choice ratio: 1.0
# Top 10 predictions: [' this', ' it', ' that', ' important', ' common', ' typical', ' true', ' different', ' fortunate', ' simple']
#
# Masked word:  is
# Probability of actual word: 0.6702890396118164
# Choice ratio: 1.0
# Top 10 predictions: [' is', ' makes', ' has', ' creates', ' affects', ' constitutes', ' causes', ' becomes', ' was', ' reflects']
#
# Masked word:  a
# Probability of actual word: 0.020513977855443954
# Choice ratio: 0.06710644934104865
# Top 10 predictions: ['.', ' why', ' because', ' the', ',', ' so', ' a', ' true', ':', ' happening']
#
# Masked word:  huge
# Probability of actual word: 0.0014780887868255377
# Choice ratio: 0.005672616558930662
# Top 10 predictions: [' problem', '...', '.', '…', ' …', ' […]', '</s>', '...', ' good', ':']
#
# Masked word:  imped
# Probability of actual word: 0.998698353767395
# Choice ratio: 1.0
# Top 10 predictions: [' imped', ' accompan', ' tax', ' sed', ' hind', ' rud', ' present', ' cond', ' imp', ' const']
#
# Masked word: iment
# Probability of actual word: 0.9993608593940735
# Choice ratio: 1.0
# Top 10 predictions: ['iment', 'iments', 'rance', 'er', 'ence', 've', 'ement', 'e', 'i', 'ider']
#
# Masked word:  to
# Probability of actual word: 0.03521348163485527
# Choice ratio: 0.03862237767106582
# Top 10 predictions: ['.', ' to', ':', ',', '...', '."', '!', ' of', ' for', ' in']
#
# Masked word:  current
# Probability of actual word: 0.00033024989534169436
# Choice ratio: 0.0017467714322926622
# Top 10 predictions: [' development', '.', ' the', ' their', ' urban', ' growth', ' cities', ' progress', ' future', ' reform']
#
# Masked word:  efforts
# Probability of actual word: 0.12228105962276459
# Choice ratio: 1.0
# Top 10 predictions: [' efforts', ' plans', ' policies', ' trends', ' progress', ' solutions', ' planning', ' policy', ' development', ' technology']
#
# Masked word:  to
# Probability of actual word: 0.0961594432592392
# Choice ratio: 0.11048440448022354
# Top 10 predictions: ['.', ' to', ':', ',', '...', '."', '…', ' of', ' and', '!']
#
# Masked word:  reduce
# Probability of actual word: 0.11824620515108109
# Choice ratio: 0.8343973727850197
# Top 10 predictions: ['.', ' reduce', ' change', '</s>', ':', ' make', ' save', '...', '…', ' cut']
#
# Masked word:  greenhouse
# Probability of actual word: 0.9885870814323425
# Choice ratio: 1.0
# Top 10 predictions: [' greenhouse', ' natural', ' car', ' air', ' road', ' household', ' the', ' vehicle', ' automobile', ' methane']
#
# Masked word:  gas
# Probability of actual word: 0.9987647533416748
# Choice ratio: 1.0
# Top 10 predictions: [' gas', ' gases', ' dioxide', ' warming', ' Gas', ' energy', ' change', ' effect', ' carbon', ' fuel']
#
# Masked word:  emissions
# Probability of actual word: 0.9645886421203613
# Choice ratio: 1.0
# Top 10 predictions: [' emissions', ' emission', '.', ' pollution', ' levels', ' production', ',', ' consumption', ' emitted', ':']
#
# Masked word:  from
# Probability of actual word: 6.371685230988078e-06
# Choice ratio: 6.680950687830777e-06
# Top 10 predictions: ['.', ':', ',', '."', '.', '...', '!', '..', '</s>', '…']
#
# Masked word:  tail
# Probability of actual word: 1.1780515052350893e-07
# Choice ratio: 4.568366810999723e-07
# Top 10 predictions: [' cars', ' cities', ' automobiles', ' transportation', ' vehicles', '.', ' driving', ' buildings', ' the', ' pollution']
#
# Masked word: pipe
# Probability of actual word: 5.028246232541278e-05
# Choice ratio: 0.0006561369063576894
# Top 10 predictions: [' vehicles', ' fuels', ' cars', ' cities', ' automobiles', ' area', ' country', ' use', ' air', ' pollution']
#
# Masked word: .
# Probability of actual word: 0.00014300151087809354
# Choice ratio: 0.0001432421344162451
# Top 10 predictions: ['</s>', '.', ' cars', ' "', '—', ' (', ' heat', '...', ' emissions', '…']
#
# New Sentence!
#
# Masked word:  Passenger
# Probability of actual word: 0.0004139026568736881
# Choice ratio: 0.012548134106211197
# Top 10 predictions: [' The', ' cars', '</s>', ' of', 'net', ' emissions', ' Cars', '0', ' And', '.']
#
# Masked word:  cars
# Probability of actual word: 0.27378174662590027
# Choice ratio: 1.0
# Top 10 predictions: [' cars', ' Cars', ' vehicles', ' car', '.', ' automobiles', ' Vehicles', ' vehicle', ' drivers', ' jets']
#
# Masked word:  are
# Probability of actual word: 0.023004800081253052
# Choice ratio: 0.03352672150669737
# Top 10 predictions: ['.', '?', ':', ' are', '!', ',', '</s>', ' also', '.', ' too']
#
# Masked word:  responsible
# Probability of actual word: 0.010472817346453667
# Choice ratio: 0.22101465739402792
# Top 10 predictions: [' used', ' called', ' reserved', ' dying', ' essential', ' popular', ' known', ' long', ' made', ' planned']
#
# Masked word:  for
# Probability of actual word: 0.7939286231994629
# Choice ratio: 1.0
# Top 10 predictions: [' for', '.', ':', ',', '?', ' to', '</s>', '!', ' of', ' that']
#
# Masked word:  12
# Probability of actual word: 0.0055886441841721535
# Choice ratio: 0.13972627089842005
# Top 10 predictions: [' 80', ' 70', ' 40', ' 90', ' 60', ' 20', ' 85', ' 75', ' 86', ' 25']
#
# Masked word:  percent
# Probability of actual word: 0.6596171855926514
# Choice ratio: 1.0
# Top 10 predictions: [' percent', '%', ' out', ' tons', ' %', ' years', ' million', ' billion', ' quarters', '%,']
#
# Masked word:  of
# Probability of actual word: 0.9952024221420288
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' global', ' more', ' in', ' the', ' annual', ' worldwide', ' total', ' US', ' to']
#
# Masked word:  greenhouse
# Probability of actual word: 0.9709495306015015
# Choice ratio: 1.0
# Top 10 predictions: [' greenhouse', ' global', ' the', ' all', ' that', ' US', ' exhaust', ' transportation', ' American', ' road']
#
# Masked word:  gas
# Probability of actual word: 0.9957669973373413
# Choice ratio: 1.0
# Top 10 predictions: [' gas', ' gases', ' dioxide', ' energy', ' air', ' carbon', ' net', ' emissions', ' Gas', ' pollution']
#
# Masked word:  emissions
# Probability of actual word: 0.9478509426116943
# Choice ratio: 1.0
# Top 10 predictions: [' emissions', ' emission', ' pollution', ' emitted', ' production', ' generation', ',', ' consumption', ' output', ' concentrations']
#
# Masked word:  in
# Probability of actual word: 0.03201594948768616
# Choice ratio: 0.03432921614652354
# Top 10 predictions: ['.', ' in', ' from', ' worldwide', ' globally', ',', '.', ' by', ':', ' of']
#
# Masked word:  Europe
# Probability of actual word: 0.06413483619689941
# Choice ratio: 0.07226780360424256
# Top 10 predictions: [' Germany', ' Europe', ' America', ' China', ' 2015', ' cities', ' Berlin', ' USA', ' 2017', ' 2016']
#
# Masked word: .
# Probability of actual word: 0.0006293777259998024
# Choice ratio: 0.0006299313540758699
# Top 10 predictions: ['</s>', '.', '."', ' (', '.', ',', ' and', ' "', '—', ',']
#
# New Sentence!
#
# Masked word:  and
# Probability of actual word: 0.0025966628454625607
# Choice ratio: 0.004867753020279635
# Top 10 predictions: ['</s>', '.', ' More', ' Next', '...', ' Close', ' Tweet', '...', ' …', '…']
#
# Masked word:  up
# Probability of actual word: 0.005403638817369938
# Choice ratio: 0.06225330916781758
# Top 10 predictions: [' according', ' Canada', ' America', ' USA', ' compared', ' continue', ' Africa', '.', ' Asia', ' China']
#
# Masked word:  to
# Probability of actual word: 0.8321768641471863
# Choice ratio: 1.0
# Top 10 predictions: [' to', '.', ' there', ' more', ' another', ' the', ' further', ' top', 'wards', ' other']
#
# Masked word:  50
# Probability of actual word: 0.04558700695633888
# Choice ratio: 0.29685827511640556
# Top 10 predictions: [' 20', ' 30', ' 40', ' 15', ' 25', ' 50', ' 14', ' 17', ' 60', ' 13']
#
# Masked word:  percent
# Probability of actual word: 0.9661781787872314
# Choice ratio: 1.0
# Top 10 predictions: [' percent', '%', ' million', ' tons', 'percent', ' %', ' billion', ' years', ',', ' Percent']
#
# Masked word:  in
# Probability of actual word: 0.14435529708862305
# Choice ratio: 0.20428372653572965
# Top 10 predictions: ['.', ' in', ' globally', ' worldwide', ',', ' of', ' for', ' elsewhere', ' at', ' on']
#
# Masked word:  some
# Probability of actual word: 0.001459338702261448
# Choice ratio: 0.00780514603183838
# Top 10 predictions: [' US', ' China', ' American', ' the', ' USA', ' UK', ' America', ' a', ' Canada', ' Germany']
#
# Masked word:  car
# Probability of actual word: 1.2120227665946004e-06
# Choice ratio: 2.1624068269391412e-06
# Top 10 predictions: [' countries', ' regions', ' places', ' areas', '.', ' states', ' locations', ' cities', ' nations', ' cases']
#
# Masked word: intensive
# Probability of actual word: 2.247711279323994e-07
# Choice ratio: 5.14751823030358e-07
# Top 10 predictions: ['.', ' country', ' countries', ' ownership', ' manufacturing', ' cities', ' driving', ' production', ' parks', ' regions']
#
# Masked word:  areas
# Probability of actual word: 0.0006652293377555907
# Choice ratio: 0.00071054430276508
# Top 10 predictions: ['.', ',', '.', ' countries', ' and', ' worldwide', ' where', '</s>', ' areas', ' states']
#
# Masked word:  in
# Probability of actual word: 0.15425843000411987
# Choice ratio: 0.21601039309641992
# Top 10 predictions: [' of', ' in', ' around', ' like', ' across', ' throughout', ' and', ',', ' outside', ' over']
#
# Masked word:  the
# Probability of actual word: 0.9990798234939575
# Choice ratio: 1.0
# Top 10 predictions: [' the', ' The', ' a', ' western', ' Southern', ' Western', ' southern', ' North', ' northern', ' America']
#
# Masked word:  United
# Probability of actual word: 0.9994332194328308
# Choice ratio: 1.0
# Top 10 predictions: [' United', ' Middle', ' US', ' Western', ' North', ' Mountain', ' Northeast', ' Midwest', ' USA', ' Northern']
#
# Masked word:  States
# Probability of actual word: 0.9898012280464172
# Choice ratio: 1.0
# Top 10 predictions: [' States', ' Kingdom', 'S', ' State', ' states', ' S', ' US', ' USA', ' West', ' STATES']
#
# Masked word: .
# Probability of actual word: 0.0020068311132490635
# Choice ratio: 0.002012831498208726
# Top 10 predictions: ['</s>', '.', ' (', '."', ' [', ',', ' "', ' …', '—', ' and']
#
# New Sentence!
#
# Masked word:  Cars
# Probability of actual word: 0.001128907548263669
# Choice ratio: 0.011052903820466642
# Top 10 predictions: [' They', ' More', ' The', '</s>', ' We', ' There', ' Both', ' These', ' Here', ' As']
#
# Masked word:  are
# Probability of actual word: 0.3290698826313019
# Choice ratio: 1.0
# Top 10 predictions: [' are', ' drive', ' dominate', ' in', ' and', ' driving', ' on', ' make', ',', ' have']
#
# Masked word:  the
# Probability of actual word: 0.7267518043518066
# Choice ratio: 1.0
# Top 10 predictions: [' the', ' their', ' also', ' not', ' our', ' a', ' second', ' another', ' most', ' driving']
#
# Masked word:  main
# Probability of actual word: 0.4477382004261017
# Choice ratio: 1.0
# Top 10 predictions: [' main', ' biggest', ' primary', ' leading', ' big', ' driving', ' real', ' major', ' only', ' key']
#
# Masked word:  reason
# Probability of actual word: 0.2950139343738556
# Choice ratio: 0.9932802488141173
# Top 10 predictions: [' driver', ' reason', ' vehicle', ' fuel', ' drivers', ' source', ' transportation', ' vehicles', ' transport', ' culprit']
#
# Masked word:  for
# Probability of actual word: 0.6331198215484619
# Choice ratio: 1.0
# Top 10 predictions: [' for', ' why', ' behind', ' that', ' of', ' in', ' to', ',', ' the', ' and']
#
# Masked word:  the
# Probability of actual word: 0.13191133737564087
# Choice ratio: 0.4770021203279369
# Top 10 predictions: [' rising', ' the', ' increasing', ' global', ' increased', ' growing', ' our', ' high', ' this', ' driving']
#
# Masked word:  greenhouse
# Probability of actual word: 0.997087299823761
# Choice ratio: 1.0
# Top 10 predictions: [' greenhouse', ' methane', ' global', ' rising', ' climate', ' high', ' warming', ' increased', ' growing', ' higher']
#
# Masked word:  gas
# Probability of actual word: 0.9910916686058044
# Choice ratio: 1.0
# Top 10 predictions: [' gas', ' gases', ' dioxide', ' Gas', ' emissions', ' net', ' energy', ' air', ' and', ' effect']
#
# Masked word:  emissions
# Probability of actual word: 0.785427451133728
# Choice ratio: 1.0
# Top 10 predictions: [' emissions', ' pollution', ' emission', ' problem', ' increase', ' crisis', ' rise', ' problems', ' levels', ' concentrations']
#
# Masked word:  because
# Probability of actual word: 0.012607209384441376
# Choice ratio: 0.13855087259216098
# Top 10 predictions: [' emissions', ' in', ' of', ' rise', ' levels', ' crisis', ' growth', ' and', ' increase', ',']
#
# Masked word:  of
# Probability of actual word: 0.7392990589141846
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' they', ' as', ' there', ' it', ' in', ' such', ' are', ' we', ' is']
#
# Masked word:  a
# Probability of actual word: 0.07911994308233261
# Choice ratio: 0.33291095993907643
# Top 10 predictions: [' the', ' a', ' pollution', '...', '</s>', ' they', '.', ':', ' their', ' emissions']
#
# Masked word:  lot
# Probability of actual word: 0.06286762654781342
# Choice ratio: 0.09895941181123113
# Top 10 predictions: [' lack', ' lot', ' combination', ' number', ' shortage', ' variety', ' history', ' problem', ' mix', ' range']
#
# Masked word:  of
# Probability of actual word: 0.9856619238853455
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' more', ' many', ' fewer', ' less', ' in', ' the', ' on', ' million', ' different']
#
# Masked word:  people
# Probability of actual word: 0.018159344792366028
# Choice ratio: 0.10272540928849859
# Top 10 predictions: [' distracted', ' car', ' the', ' daily', ' urban', ' reckless', ' human', ' road', ' highway', ' vehicle']
#
# Masked word:  driving
# Probability of actual word: 0.7829269170761108
# Choice ratio: 1.0
# Top 10 predictions: [' driving', ' using', ' in', ' around', ' owning', ' buying', ' riding', ' behind', ' inside', ' avoiding']
#
# Masked word:  them
# Probability of actual word: 0.4981348514556885
# Choice ratio: 1.0
# Top 10 predictions: [' them', ' cars', ' all', ' around', ' themselves', ' vehicles', ' it', ' and', ' straight', ' people']
#
# Masked word:  around
# Probability of actual word: 0.0034062499180436134
# Choice ratio: 0.003922559889894242
# Top 10 predictions: ['.', ' and', ',', ' in', ' after', ' for', ' at', ' by', '!', ' around']
#
# Masked word:  all
# Probability of actual word: 0.0612296536564827
# Choice ratio: 0.08987468230394709
# Top 10 predictions: [' in', ' on', ' and', ' all', ',', ' during', ' with', ' at', ' to', ' especially']
#
# Masked word:  the
# Probability of actual word: 0.9997598528862
# Choice ratio: 1.0
# Top 10 predictions: [' the', 'the', ' this', ' of', ' that', ' over', ' day', ' their', ' The', ' single']
#
# Masked word:  time
# Probability of actual word: 0.9984183311462402
# Choice ratio: 1.0
# Top 10 predictions: [' time', ' times', ' while', ' world', ' place', ' way', ' same', ' day', ' country', ' Time']
#
# Masked word:  getting
# Probability of actual word: 0.00014527898747473955
# Choice ratio: 0.00026106600350858287
# Top 10 predictions: [',', ' in', ' and', ' to', ' from', ' especially', ' at', ' or', ' except', ' every']
#
# Masked word:  where
# Probability of actual word: 0.197551891207695
# Choice ratio: 1.0
# Top 10 predictions: [' where', ' what', ' around', ' things', ' nowhere', ' everything', ' into', ' to', ' fuel', ' in']
#
# Masked word:  they
# Probability of actual word: 0.9564687609672546
# Choice ratio: 1.0
# Top 10 predictions: [' they', ' you', ' we', ' people', ' their', ' the', ' I', ' things', ' to', ' are']
#
# Masked word:  need
# Probability of actual word: 0.6304112076759338
# Choice ratio: 1.0
# Top 10 predictions: [' need', ' want', ' have', ' like', ' wanted', ' needed', ' get', ' go', ' used', ' got']
#
# Masked word:  to
# Probability of actual word: 0.9999287128448486
# Choice ratio: 1.0
# Top 10 predictions: [' to', 'to', ' them', ' ot', ' or', ' and', ' they', ' too', ' a', ' the']
#
# Masked word:  go
# Probability of actual word: 0.7280142903327942
# Choice ratio: 1.0
# Top 10 predictions: [' go', ' get', ' be', ' travel', ' live', ' going', ' work', ' drive', ' stay', ' meet']
#
# Masked word: .
# Probability of actual word: 0.0006060877349227667
# Choice ratio: 0.0006065476741349903
# Top 10 predictions: ['</s>', '.', ' (', ' and', ',', '."', '.', ' "', '—', ' [']
#
# New Sentence!
#
# Masked word:  Article
# Probability of actual word: 5.076954039395787e-06
# Choice ratio: 2.180956551951142e-05
# Top 10 predictions: [' So', ' However', ' Therefore', ' But', ' Also', '</s>', ' Now', ' Thus', ' Today', ' Unfortunately']
#
# Masked word: ,
# Probability of actual word: 0.0013734664535149932
# Choice ratio: 0.005254484036783303
# Top 10 predictions: [':', ' :', ' Continued', ' 1', ' Summary', ' I', ' continues', ' summary', ' by', ' 21']
#
# Masked word:  "
# Probability of actual word: 0.00045514394878409803
# Choice ratio: 0.0034273622784919567
# Top 10 predictions: ['</s>', ' Wikipedia', ' 2017', ' 2015', ' 2016', ' 2013', ' 2014', ' 2018', ' Reuters', ' by']
#
# Masked word: Paris
# Probability of actual word: 0.00044254297972656786
# Choice ratio: 0.007894458097695345
# Top 10 predictions: ['</s>', '."', '"', ' "', '">', 'EPA', '...', 'more', 'More', 'The']
#
# Masked word:  bans
# Probability of actual word: 1.5269027926478884e-06
# Choice ratio: 2.4412220075018034e-06
# Top 10 predictions: ['"', '."', '".', '":', '"...', ',"', '",', ' "', '..."', '."']
#
# Masked word:  driving
# Probability of actual word: 9.945634701580275e-06
# Choice ratio: 1.6188507429626473e-05
# Top 10 predictions: ['"', '."', ',"', '",', ' are', '".', '":', ',', '.', ':']
#
# Masked word:  due
# Probability of actual word: 0.01354691106826067
# Choice ratio: 0.05535778124197751
# Top 10 predictions: ['."', '"', ',"', ' in', ' around', ' cars', ' vehicles', ' on', ' "', ' due']
#
# Masked word:  to
# Probability of actual word: 0.45176219940185547
# Choice ratio: 1.0
# Top 10 predictions: [' to', ' pollution', '...', '"', '."', ' "', ' heat', ' emissions', '…', ' …']
#
# Masked word:  sm
# Probability of actual word: 0.00044466715189628303
# Choice ratio: 0.0008091086259024182
# Top 10 predictions: [' pollution', ' heat', ' traffic', ' fumes', ' emissions', ' noise', ' congestion', ' "', ' cars', ' smoke']
#
# Masked word: og
# Probability of actual word: 0.9998080134391785
# Choice ratio: 1.0
# Top 10 predictions: ['og', 'ogs', 'elly', 'elt', 'ot', 'udge', 'ells', 'ut', 'udging', 'oky']
#
# Masked word: ,"
# Probability of actual word: 0.05333630368113518
# Choice ratio: 0.10562190423434406
# Top 10 predictions: ['"', '."', ',"', '".', '":', '",', '..."', ';"', '";', '.']
#
# Masked word:  by
# Probability of actual word: 0.16756469011306763
# Choice ratio: 1.0
# Top 10 predictions: [' by', '</s>', ' 2017', ' 2018', ' 2016', ' Reuters', ' Bloomberg', ' 2015', ' 2014', ' in']
#
# Masked word:  Robert
# Probability of actual word: 0.0018524352926760912
# Choice ratio: 0.0076729932069088454
# Top 10 predictions: [':', ' Reuters', ' Bloomberg', ' AP', '.', ' AFP', ' Paul', ' David', ' :', ' Daniel']
#
# Masked word:  D
# Probability of actual word: 0.00020921530085615814
# Choice ratio: 0.009472591137806179
# Top 10 predictions: [' Reich', ' Costa', ' Kaplan', ' Gibbs', ' Cohen', ' Klein', ' Miller', ' Burns', ' Weiss', ' Wood']
#
# Masked word: uffer
# Probability of actual word: 0.000725950812920928
# Choice ratio: 0.005728754425380503
# Top 10 predictions: ['aley', 'yer', 'utton', '.', 'yson', 'enton', 'iller', 'olan', 'ennett', 'ickson']
#
# Masked word:  says
# Probability of actual word: 1.1983381682512118e-06
# Choice ratio: 1.2192632675739542e-06
# Top 10 predictions: ['in', 'ins', ' Ferguson', 'ings', 'iner', 'yn', 'er', 'en', 'on', 'it']
#
# Masked word: ,
# Probability of actual word: 0.03459229692816734
# Choice ratio: 0.07674050674755883
# Top 10 predictions: [' about', ' exactly', ' just', ' of', ',', ' on', ' that', ' how', ':', ' the']
#
# Masked word:  how
# Probability of actual word: 9.818223770707846e-05
# Choice ratio: 0.0005080539973185069
# Top 10 predictions: [' "', ' in', ' more', ' via', ' at', ' |', ' by', ' «', ':', ' -']
#
# Masked word:  Paris
# Probability of actual word: 0.0002143667807104066
# Choice ratio: 0.0021654202753307646
# Top 10 predictions: [' about', '?', ' much', 'ever', ':', ' the', ' many', ',', ' to', ' come']
#
# Masked word: ,
# Probability of actual word: 0.011894301511347294
# Choice ratio: 0.07779044661822726
# Top 10 predictions: [' works', ' reacts', ' reacted', ' responded', ' voted', ' fared', ' happened', ' developed', ' changed', ' started']
#
# Masked word:  after
# Probability of actual word: 0.0009921531891450286
# Choice ratio: 0.002999047230881186
# Top 10 predictions: [' France', ' 2015', ' California', ' […]', ' the', ' Paris', ' Germany', ' 2017', '?', ' 2016']
#
# Masked word:  days
# Probability of actual word: 0.002684815088286996
# Choice ratio: 0.006490934899999373
# Top 10 predictions: [' years', ' decades', ' thousands', ' hundreds', ' millions', ' dozens', ' the', ' months', ' all', ' centuries']
#
# Masked word:  of
# Probability of actual word: 0.4616018235683441
# Choice ratio: 1.0
# Top 10 predictions: [' of', ',', '...', '.', ' later', ' |', ' after', '…', '</s>', ' in']
#
# Masked word:  near
# Probability of actual word: 8.018033440748695e-06
# Choice ratio: 1.6826787325605737e-05
# Top 10 predictions: [' protests', ' protest', ' demonstrations', ' smoke', ' rain', ' debate', ' pollution', ' campaigning', ' darkness', ' unrest']
#
# Masked word: record
# Probability of actual word: 0.0016618219669908285
# Choice ratio: 0.0075819076250996575
# Top 10 predictions: [' zero', ' toxic', ' record', ' choking', ' total', ' perfect', ' daily', ' unprecedented', ' global', ' unbearable']
#
# Masked word:  pollution
# Probability of actual word: 0.049825798720121384
# Choice ratio: 0.12522233851583928
# Top 10 predictions: [' heat', ' temperatures', ' highs', ' pollution', ' cold', ' warmth', ' rain', ' weather', ' fog', ' rainfall']
#
# Masked word: ,
# Probability of actual word: 0.7158052921295166
# Choice ratio: 1.0
# Top 10 predictions: [',', '.', ':', '...', '?', '."', ',', '…', ',...', '...']
#
# Masked word:  enforced
# ...
#
# Masked word:  repair
# Probability of actual word: 0.0005306865787133574
# Choice ratio: 0.0017778419912785647
# Top 10 predictions: ['.', ' have', ' develop', ' build', ' use', ' create', '...', ' adopt', ' pave', ' get']
#
# Masked word:  sidewalks
# Probability of actual word: 0.0003444980247877538
# Choice ratio: 0.0007830155065555011
# Top 10 predictions: [' things', ' and', ' cars', ' themselves', ' buildings', ' infrastructure', ' roads', ' more', ' them', ' problems']
#
# Masked word: ,
# Probability of actual word: 0.9845516085624695
# Choice ratio: 1.0
# Top 10 predictions: [',', ' more', ' faster', ' better', '.', ';', ' again', ' quicker', ' themselves', ' regularly']
#
# Masked word:  and
# Probability of actual word: 0.49070724844932556
# Choice ratio: 1.0
# Top 10 predictions: [' and', ' etc', ' traffic', ' it', ' which', ' trees', ' roads', ' they', ' the', ' parks']
#
# Masked word:  cut
# Probability of actual word: 0.004834851715713739
# Choice ratio: 0.020956471960360754
# Top 10 predictions: [' traffic', ' slow', ' slowing', ' restaurants', ' trees', ' slowed', ' slows', ' drive', ' calming', ' shut']
#
# Masked word:  down
# Probability of actual word: 0.646177351474762
# Choice ratio: 1.0
# Top 10 predictions: [' down', ' the', ' back', ' off', ' their', ' car', ' foot', ' in', ' up', ' more']
#
# Masked word:  traffic
# Probability of actual word: 0.6752309203147888
# Choice ratio: 1.0
# Top 10 predictions: [' traffic', '.', ' crime', ' on', ' parking', ' the', ' shopping', ' Traffic', '...', ' tourism']
#
# Masked word:  jams
# Probability of actual word: 0.738027036190033
# Choice ratio: 1.0
# Top 10 predictions: [' jams', ' congestion', ' loads', ' too', ' accidents', ' volumes', ' levels', ' jam', ' altogether', ' problems']
#
# Masked word: .
# Probability of actual word: 0.0012782859848812222
# Choice ratio: 0.0012803013824006439
# Top 10 predictions: ['</s>', '.', ',', ' and', ' (', '..', '."', ' "', ',,', '!']
#
# New Sentence!
#
# Masked word:  Lim
# Probability of actual word: 8.77901584317442e-06
# Choice ratio: 1.0606258389207638e-05
# Top 10 predictions: ['</s>', '.', ' Advertisement', ' …', ' […]', '...', ' More', ' Conclusion', '…', ' Results']
#
# Masked word: iting
# Probability of actual word: 0.6613361835479736
# Choice ratio: 1.0
# Top 10 predictions: ['iting', ',', 'ing', 'ping', ' of', ' to', 'itations', 'inating', 'ming', ' is']
#
# Masked word:  the
# Probability of actual word: 0.004488589707762003
# Choice ratio: 0.004988014428877082
# Top 10 predictions: [' car', ' automobile', ' vehicle', ' their', ' cars', ' auto', ' road', ' the', ' driving', ' gas']
#
# Masked word:  use
# Probability of actual word: 0.66270512342453
# Choice ratio: 1.0
# Top 10 predictions: [' use', ' number', ' usage', ' amount', ' traffic', ' consumption', ' impact', ' driving', ' numbers', ' speed']
#
# Masked word:  of
# Probability of actual word: 0.9973002076148987
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' the', ' for', ' on', ' in', ' by', ' more', ' a', ' electric', ' to']
#
# Masked word:  cars
# Probability of actual word: 0.962493896484375
# Choice ratio: 1.0
# Top 10 predictions: [' cars', ' automobiles', ' vehicles', ' car', ' autos', ' them', ' Cars', ' roads', ' drivers', ' driving']
#
# Masked word:  would
# Probability of actual word: 0.008605976589024067
# Choice ratio: 0.017676004212218075
# Top 10 predictions: ['.', ',', ' by', ' can', ' to', ' and', ' will', ' is', ' has', ' should']
#
# Masked word:  be
# Probability of actual word: 0.8185601234436035
# Choice ratio: 1.0
# Top 10 predictions: [' be', ' have', ' make', ' mean', ' create', ' take', ' cause', ' require', ' not', ' do']
#
# Masked word:  a
# Probability of actual word: 0.7712016701698303
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' very', ' really', ' good', ' extremely', ' another', ' the', ' more', ' considered', ' an']
#
# Masked word:  good
# Probability of actual word: 0.8527483344078064
# Choice ratio: 1.0
# Top 10 predictions: [' good', ' great', ' bad', ' wonderful', ' positive', ' terrible', ' nice', ' wise', ' better', ' smart']
#
# Masked word:  thing
# Probability of actual word: 0.19785277545452118
# Choice ratio: 0.44823792070849117
# Top 10 predictions: [' idea', ' thing', ' solution', ' move', ' way', ' step', ' strategy', ' policy', ' cause', ' reason']
#
# Masked word:  for
# Probability of actual word: 0.04507515951991081
# Choice ratio: 0.04959008063548899
# Top 10 predictions: ['.', ' for', ',', '!', ' in', ' to', '...', '…', ' of', ' because']
#
# Masked word:  America
# Probability of actual word: 0.03130593150854111
# Choice ratio: 0.039201272753341364
# Top 10 predictions: [' Columbia', ' everyone', ' America', ' cities', ' Canada', ' society', ' everybody', ' all', ' us', ' citizens']
#
# Masked word: .
# Probability of actual word: 0.00013145730190444738
# Choice ratio: 0.00013148285832578692
# Top 10 predictions: ['</s>', '.', ',', ' and', ' (', ' "', '..', ',', '.', '<s>']
#
# New Sentence!
#
# Masked word:  So
# Probability of actual word: 0.03341693431138992
# Choice ratio: 0.1534030922601014
# Top 10 predictions: [' If', '</s>', ' And', ' So', ' But', ' Now', ' We', ' Maybe', ' When', ' What']
#
# Masked word:  we
# Probability of actual word: 0.5846375823020935
# Choice ratio: 1.0
# Top 10 predictions: [' we', ' it', ' they', ' this', ' America', ' that', ' Americans', ' you', ',', ' cities']
#
# Masked word:  should
# Probability of actual word: 0.6312119960784912
# Choice ratio: 1.0
# Top 10 predictions: [' should', ' can', ' could', ' must', ' would', ' will', ' might', ' may', ' need', ' cannot']
#
# Masked word:  limit
# Probability of actual word: 0.1411777138710022
# Choice ratio: 0.7674882212945774
# Top 10 predictions: [' reduce', ' do', ' limit', ' see', ' restrict', ' have', ' consider', ' increase', ' stop', ' start']
#
# Masked word:  the
# Probability of actual word: 0.15145935118198395
# Choice ratio: 0.27249300903685936
# Top 10 predictions: [' car', ' their', ' the', ' our', ' cars', ' automobile', ' its', ' vehicle', ' auto', ' that']
#
# Masked word:  use
# Probability of actual word: 0.8525938987731934
# Choice ratio: 1.0
# Top 10 predictions: [' use', ' number', ' usage', ' amount', ' consumption', ' uses', ' traffic', ' numbers', ' driving', ' fleet']
#
# Masked word:  of
# Probability of actual word: 0.998346209526062
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' the', ' in', ' for', ' on', ' by', ' if', ' our', ' to', ' more']
#
# Masked word:  cars
# Probability of actual word: 0.7540416717529297
# Choice ratio: 1.0
# Top 10 predictions: [' cars', ' car', ',', '.', '...', ' automobiles', ' the', ' vehicles', '…', '</s>']
#
# Masked word:  by
# Probability of actual word: 0.0019124412210658193
# Choice ratio: 0.0029262599392634956
# Top 10 predictions: ['.', ',', ' and', ' to', '...', '?', '…', '...', ' or', ' more']
#
# Masked word:  maybe
# Probability of actual word: 3.848443884635344e-05
# Choice ratio: 0.0003069516124003831
# Top 10 predictions: [' cities', '.', ' Americans', ' people', ':', ' 2030', '.', ' driving', ' 2025', ' citizens']
#
# Masked word:  riding
# Probability of actual word: 3.291595567134209e-05
# Choice ratio: 0.00013593811676653576
# Top 10 predictions: [' half', ' about', ' having', ' just', ',', ' even', ' maybe', ' only', ' doing', ' starting']
#
# Masked word:  a
# Probability of actual word: 0.7503315806388855
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' our', ' your', ' the', ' more', ' my', ' on', ' some', ' less', ' that']
#
# Masked word:  bike
# Probability of actual word: 0.5276064872741699
# Choice ratio: 1.0
# Top 10 predictions: [' bike', ' bicycle', ' bus', ' motorcycle', ' horse', ' train', ' cyclist', ' subway', ' taxi', ' cycle']
#
# Masked word: ,
# Probability of actual word: 0.9358696937561035
# Choice ratio: 1.0
# Top 10 predictions: [',', ' more', ' instead', ' together', ' path', ' downtown', ' home', ' or', ' less', ' maybe']
#
# Masked word:  or
# Probability of actual word: 0.8149199485778809
# Choice ratio: 1.0
# Top 10 predictions: [' or', ' and', ' maybe', ' then', ' by', ' but', ' even', ' like', ' to', ' a']
#
# Masked word:  maybe
# Probability of actual word: 0.6843653321266174
# Choice ratio: 1.0
# Top 10 predictions: [' maybe', ' by', ' just', ' perhaps', ' even', ' simply', ' going', ',', ' possibly', ' a']
#
# Masked word:  walking
# Probability of actual word: 0.6686211228370667
# Choice ratio: 1.0
# Top 10 predictions: [' walking', ' going', ' driving', ' biking', ' walk', ' hiking', ' cycling', ' running', ' traveling', ' riding']
#
# Masked word:  somewhere
# Probability of actual word: 0.0017604246968403459
# Choice ratio: 0.0037231350561038215
# Top 10 predictions: [',', ' so', '.', ' or', ' and', ' like', ' such', '...', ' enough', ' …']
#
# Masked word:  that
# Probability of actual word: 0.0008707171655260026
# Choice ratio: 0.0009096679324455169
# Top 10 predictions: ['.', ',', ' else', '?', '!', '...', ' different', ' nearby', ' that', ' safe']
#
# Masked word:  isn
# Probability of actual word: 0.9514093995094299
# Choice ratio: 1.0
# Top 10 predictions: [' isn', ' doesn', ' wasn', ' aren', ' can', ' shouldn', ' won', ' don', ' hasn', ' ain']
#
# Masked word: 't
# Probability of actual word: 0.9975802898406982
# Choice ratio: 1.0
# Top 10 predictions: ["'t", ' not', "'s", ',', ' really', "'", '...', ' t', '.', 't']
#
# Masked word:  that
# Probability of actual word: 0.11182264983654022
# Choice ratio: 0.17108145641941855
# Top 10 predictions: [' too', ' very', ' that', ' so', ' really', ' to', ' terribly', ' necessarily', ' as', ' quite']
#
# Masked word:  far
# Probability of actual word: 0.9956157207489014
# Choice ratio: 1.0
# Top 10 predictions: [' far', ' distant', ' long', ' different', ' close', ' much', ' bad', ' great', ' distance', ' remote']
#
# Masked word:  from
# Probability of actual word: 0.0373273640871048
# Choice ratio: 0.043679534190427374
# Top 10 predictions: ['.', ',', ' from', ' away', '?', ' or', '...', ' and', ' to', '!']
#
# Masked word:  you
# Probability of actual word: 0.015413993038237095
# Choice ratio: 0.05503389569318363
# Top 10 predictions: [' home', ' downtown', ' work', ' traffic', ' cars', ' campus', ',', ' here', ' school', ' civilization']
#
# Masked word:  and
# Probability of actual word: 0.00014196231495589018
# Choice ratio: 0.0001477677136981666
# Top 10 predictions: ['.', '?', ',', '...', '!', '</s>', '…', '."', ' …', '...']
#
# Masked word:  doesn
# Probability of actual word: 0.06304916739463806
# Choice ratio: 0.07008886094200152
# Top 10 predictions: [' isn', ' doesn', ' won', ' shouldn', ' can', ' aren', ' hasn', ' don', ' wasn', ' wouldn']
#
# Masked word: 't
# Probability of actual word: 0.9996179342269897
# Choice ratio: 1.0
# Top 10 predictions: ["'t", 'uts', 'ut', "'", 'ato', 'ot', 'ates', 'ada', "'s", 'oth']
#
# Masked word:  need
# Probability of actual word: 0.06992735713720322
# Choice ratio: 0.31524908177801797
# Top 10 predictions: [' have', ' affect', ' involve', ' require', ' need', ' hurt', ' impact', ' disturb', ' block', ' touch']
#
# Masked word:  the
# Probability of actual word: 0.11783182621002197
# Choice ratio: 0.29745480677301805
# Top 10 predictions: [' to', ' the', ' car', ' your', '.', ' you', ' much', ' automobile', ' public', ' any']
#
# Masked word:  use
# Probability of actual word: 0.12729041278362274
# Choice ratio: 1.0
# Top 10 predictions: [' use', ' cars', ' car', ' presence', ' transportation', ' traffic', ' attention', ' maintenance', ' hassle', ' upkeep']
#
# Masked word:  of
# Probability of actual word: 0.9983419179916382
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' or', ' for', ',', ' is', ' such', ' if', ' up', ' in', ' as']
#
# Masked word:  a
# Probability of actual word: 0.6351296901702881
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' the', ' your', ' that', ' any', ' another', ' you', ' our', ' their', ' electric']
#
# Masked word:  car
# Probability of actual word: 0.8925914764404297
# Choice ratio: 1.0
# Top 10 predictions: [' car', ' vehicle', ' driver', ' motor', ' bus', ' lot', ' machine', ' taxi', ' bike', ' road']
#
# Masked word:  to
# Probability of actual word: 0.00121368991676718
# Choice ratio: 0.0012406798468256196
# Top 10 predictions: ['.', '?', ',', ' to', '!', '...', ' …', '…', '."', '</s>']
#
# Masked word:  get
# Probability of actual word: 0.2573484480381012
# Choice ratio: 1.0
# Top 10 predictions: [' get', ' reach', ' transport', ' take', ' carry', ' drive', ' walk', ' follow', ' move', ' bring']
#
# Masked word:  you
# Probability of actual word: 0.9462058544158936
# Choice ratio: 1.0
# Top 10 predictions: [' you', ' to', ' down', ' out', ' over', ' yourself', ' from', ' around', ' us', ' back']
#
# Masked word:  there
# Probability of actual word: 0.5559530854225159
# Choice ratio: 1.0
# Top 10 predictions: [' there', ' around', ' anywhere', ' somewhere', ' home', ' to', ' places', ' across', ' by', ' everywhere']
#
# Masked word: .
# Probability of actual word: 0.002155561465770006
# Choice ratio: 0.0021616165425499484
# Top 10 predictions: ['</s>', '.', ',', ' and', '?', ' (', '."', ' that', '..', ' [']
#
# New Sentence!
#
# Masked word:  To
# Probability of actual word: 0.003252338385209441
# Choice ratio: 0.005493203621117912
# Top 10 predictions: ['</s>', ' By', ' So', ' Maybe', '.', ' For', ' Or', ' Just', ' And', ' But']
#
# Masked word:  me
# Probability of actual word: 0.0707627609372139
# Choice ratio: 0.32620237452482714
# Top 10 predictions: [' say', ' conclude', ' summarize', ' me', ' end', ' think', ' add', ' wit', ' go', ' recap']
#
# Masked word: ,
# Probability of actual word: 0.6880773901939392
# Choice ratio: 1.0
# Top 10 predictions: [',', '.', ':', '?', '...', ' that', ' the', ' …', ' this', '...']
#
# Masked word:  limiting
# Probability of actual word: 0.12988272309303284
# Choice ratio: 0.9498504764028204
# Top 10 predictions: [' that', ' limiting', ' maybe', ' it', ' this', ' just', ' reducing', ' limit', ' what', ' limits']
#
# Masked word:  the
# Probability of actual word: 0.49913015961647034
# Choice ratio: 1.0
# Top 10 predictions: [' the', ' car', ' their', ' vehicle', ' automobile', ' cars', ' auto', ' our', ' its', ' that']
#
# Masked word:  use
# Probability of actual word: 0.9381804466247559
# Choice ratio: 1.0
# Top 10 predictions: [' use', ' usage', ' number', ' amount', ' uses', ' need', ' kind', ' using', ' choice', ' …']
#
# Masked word:  of
# Probability of actual word: 0.9995493292808533
# Choice ratio: 1.0
# Top 10 predictions: [' of', ' in', ' if', ' for', ' by', ' is', ' to', ' on', ' the', ' or']
#
# Masked word:  cars
# Probability of actual word: 0.9608984589576721
# Choice ratio: 1.0
# Top 10 predictions: [' cars', ' car', ' the', ' automobiles', ' vehicles', ' a', ' people', ' what', ' roads', ' that']
#
# Masked word:  might
# Probability of actual word: 0.012325461953878403
# Choice ratio: 0.018510411869253455
# Top 10 predictions: [' would', ' should', '.', ' is', ' will', ' might', ' means', ',', '?', '...']
#
# Masked word:  be
# Probability of actual word: 0.8843186497688293
# Choice ratio: 1.0
# Top 10 predictions: [' be', ' seem', ' sound', ' make', ' like', ' look', ' mean', ' have', ' represent', ' work']
#
# Masked word:  a
# Probability of actual word: 0.9927041530609131
# Choice ratio: 1.0
# Top 10 predictions: [' a', ' very', ' really', ' pretty', ' the', ' quite', ' some', ' considered', ' another', ' too']
#
# Masked word:  good
# Probability of actual word: 0.9408299326896667
# Choice ratio: 1.0
# Top 10 predictions: [' good', ' bad', ' great', ' positive', ' nice', ' better', ' terrible', ' smart', ' healthy', ' big']
#
# Masked word:  thing
# Probability of actual word: 0.11345738172531128
# Choice ratio: 0.18880872986163144
# Top 10 predictions: [' way', ' thing', ' idea', ' solution', ' place', ' start', ' approach', ' reason', ' move', ' answer']
#
# Masked word:  to
# Probability of actual word: 0.06699925661087036
# Choice ratio: 0.07868076870579259
# Top 10 predictions: ['.', ' to', ':', '...', ' for', '</s>', ',', '!', '?', ' because']
#
# Masked word:  do
# Probability of actual word: 0.48089441657066345
# Choice ratio: 1.0
# Top 10 predictions: [' do', ' America', ' have', ' Americans', ' us', ' happen', ' try', ' American', ' society', ' me']
#
# Masked word: .
# Probability of actual word: 5.7917630329029635e-05
# Choice ratio: 5.792557829138684e-05
# Top 10 predictions: ['</s>', '.', '—', ' (', ' and', ' that', '?', '...', ' because', ' "']

# %%
        target_token = tokens['input_ids'][0, i]

        with torch.no_grad():
            outputs = model(masked_tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, i])
        top_50 = torch.topk(probabilities, 10, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token].item()
        top_word_prob = probabilities[top_50.indices[0]].item()
        choice_ratio = actual_word_prob / top_word_prob

        print(f'Masked word: {tokenizer.decode([target_token])}')
        print('Probability of actual word:', actual_word_prob)
        print('Choice ratio:', choice_ratio)
        print('Top 10 predictions:', top_50_words, end='\n\n')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> model(masked_tokens)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:1084, in RobertaForMaskedLM.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, output_attentions, output_hidden_states, return_dict)
#    1074 r"""
#    1075 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1076     Labels for computing the masked language modeling loss. Indices should be in `[-100, 0, ...,
#    (...)
#    1080     Used to hide legacy arguments that have been deprecated.
#    1081 """
#    1082 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1084 outputs = self.roberta(
#    1085     input_ids,
#    1086     attention_mask=attention_mask,
#    1087     token_type_ids=token_type_ids,
#    1088     position_ids=position_ids,
#    1089     head_mask=head_mask,
#    1090     inputs_embeds=inputs_embeds,
#    1091     encoder_hidden_states=encoder_hidden_states,
#    1092     encoder_attention_mask=encoder_attention_mask,
#    1093     output_attentions=output_attentions,
#    1094     output_hidden_states=output_hidden_states,
#    1095     return_dict=return_dict,
#    1096 )
#    1097 sequence_output = outputs[0]
#    1098 prediction_scores = self.lm_head(sequence_output)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:782, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     780     raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#     781 elif input_ids is not None:
# --> 782     self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#     783     input_shape = input_ids.size()
#     784 elif inputs_embeds is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/modeling_utils.py:4116, in PreTrainedModel.warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    4113     return
#    4115 # Check only the first and last input IDs to reduce overhead.
# -> 4116 if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    4117     warn_string = (
#    4118         "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#    4119         "https://huggingface.co/docs/transformers/troubleshooting"
#    4120         "#incorrect-output-when-padding-tokens-arent-masked."
#    4121     )
#    4123     # If the pad token is equal to either BOS, EOS, or SEP, we do not know whether the user should use an
#    4124     # attention_mask or not. In this case, we should still show a warning because this is a rare case.
#
# IndexError: index is out of bounds for dimension with size 0

# %%
masked_tokens
# Out:
# tensor([], size=(1, 0), dtype=torch.int64)

# %%
text = train_essays['text'][0]

sentence_list = text.split('.')
sentence_list = [sentence.strip() for sentence in sentence_list]
sentence_list = [sentence for sentence in sentence_list if sentence]

tokenizer = AutoTokenizer.from_pretrained('roberta-base')
model = AutoModelForMaskedLM.from_pretrained('roberta-base')

for i, sentence in enumerate(sentence_list):
    print('New Sentence!', end='\n\n')

    # Split the sentence into words
    words = sentence.split()

    for j, word in enumerate(words):
        # Context is the part of the sentence before the current word
        context = ' '.join(words[:j])
        masked_sentence = context + ' ' + tokenizer.mask_token if context else tokenizer.mask_token

        # Tokenize the masked sentence
        tokens = tokenizer(masked_sentence, return_tensors='pt', add_special_tokens=False)
        
        masked_index = tokens['input_ids'][0].tolist().index(tokenizer.mask_token_id)
        target_token = tokenizer.encode(word, add_special_tokens=False)[0]

        with torch.no_grad():
            outputs = model(tokens)
            logits = outputs.logits

        softmax = torch.nn.Softmax(dim=-1)
        probabilities = softmax(logits[0, masked_index])
        top_50 = torch.topk(probabilities, 10, dim=0)
        top_50_words = [tokenizer.decode([idx]) for idx in top_50.indices.tolist()]
        actual_word_prob = probabilities[target_token].item()
        top_word_prob = probabilities[top_50.indices[0]].item()
        choice_ratio = actual_word_prob / top_word_prob

        print(f'Masked word: {tokenizer.decode([target_token])}')
        print('Probability of actual word:', actual_word_prob)
        print('Choice ratio:', choice_ratio)
        print('Top 10 predictions:', top_50_words, end='\n\n')
# Out:
# New Sentence!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb Cell 24 line 2
#      <a href='vscode-notebook-cell:/Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb#X44sZmlsZQ%3D%3D?line=24'>25</a> target_token = tokenizer.encode(word, add_special_tokens=False)[0]
#      <a href='vscode-notebook-cell:/Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb#X44sZmlsZQ%3D%3D?line=26'>27</a> with torch.no_grad():
# ---> <a href='vscode-notebook-cell:/Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb#X44sZmlsZQ%3D%3D?line=27'>28</a>     outputs = model(tokens)
#      <a href='vscode-notebook-cell:/Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb#X44sZmlsZQ%3D%3D?line=28'>29</a>     logits = outputs.logits
#      <a href='vscode-notebook-cell:/Users/claygendron/Git/Repos/llm-detect-ai-generated-text/playground.ipynb#X44sZmlsZQ%3D%3D?line=30'>31</a> softmax = torch.nn.Softmax(dim=-1)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:1084, in RobertaForMaskedLM.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, output_attentions, output_hidden_states, return_dict)
#    1074 r"""
#    1075 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1076     Labels for computing the masked language modeling loss. Indices should be in `[-100, 0, ...,
#    (...)
#    1080     Used to hide legacy arguments that have been deprecated.
#    1081 """
#    1082 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1084 outputs = self.roberta(
#    1085     input_ids,
#    1086     attention_mask=attention_mask,
#    1087     token_type_ids=token_type_ids,
#    1088     position_ids=position_ids,
#    1089     head_mask=head_mask,
#    1090     inputs_embeds=inputs_embeds,
#    1091     encoder_hidden_states=encoder_hidden_states,
#    1092     encoder_attention_mask=encoder_attention_mask,
#    1093     output_attentions=output_attentions,
#    1094     output_hidden_states=output_hidden_states,
#    1095     return_dict=return_dict,
#    1096 )
#    1097 sequence_output = outputs[0]
#    1098 prediction_scores = self.lm_head(sequence_output)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:782, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     780     raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#     781 elif input_ids is not None:
# --> 782     self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#     783     input_shape = input_ids.size()
#     784 elif inputs_embeds is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/modeling_utils.py:4116, in PreTrainedModel.warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    4113     return
#    4115 # Check only the first and last input IDs to reduce overhead.
# -> 4116 if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    4117     warn_string = (
#    4118         "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#    4119         "https://huggingface.co/docs/transformers/troubleshooting"
#    4120         "#incorrect-output-when-padding-tokens-arent-masked."
#    4121     )
#    4123     # If the pad token is equal to either BOS, EOS, or SEP, we do not know whether the user should use an
#    4124     # attention_mask or not. In this case, we should still show a warning because this is a rare case.
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:255, in BatchEncoding.__getitem__(self, item)
#     253     return self.data[item]
#     254 elif self._encodings is not None:
# --> 255     return self._encodings[item]
#     256 elif isinstance(item, slice):
#     257     return {key: self.data[key][item] for key in self.data.keys()}
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# Assuming train_essays is a DataFrame with a column 'text'
text = train_essays['text'][0]

# Split and clean sentences
sentence_list = [sentence.strip() for sentence in text.split('.') if sentence.strip()]

# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('roberta-base')
model = AutoModelForMaskedLM.from_pretrained('roberta-base')

# %%
text = train_essays['text']

sentence_list = text.split('.')
sentence_list

for i, sentence in enumerate(sentence_list):
    section_start = i - 2
    section_end = i + 2
    if section_start < 0:
        section_start = 0
    if section_end > len(sentence_list):
        section_end = len(sentence_list)
        
    section = ''
    for j in range(section_start, section_end):
        section += sentence_list[j].strip() + '. '
    section = section.strip()
    
    sentence_num = i - section_start + 1
